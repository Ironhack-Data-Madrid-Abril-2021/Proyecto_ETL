# %%
#Average price of residential property
#(120 square meter apartments located in the most important cities) in Europe as of September 2020, per country

# %%
import pandas as pd
import numpy as np

# %%
#Primera fuente de CSV

df1 = pd.read_excel("average_residetial.xlsx","Data")

# %%
df1 = df1.fillna('-') #Para sustituir los NaNs

# %%
df1 = df1.rename(columns={'Unnamed: 0':'indice', 'Unnamed: 1': 'paises', 'Unnamed: 2': 'precio_m2'})

# %%
df1 = df1.drop([0,1,2,3], axis=0)

# %%
df1.head()
# Out:
#   indice       paises precio_m2
# 4      -       Monaco     44522
# 5      -           UK     21179
# 6      -  Switzerland     13280
# 7      -       France     12796
# 8      -      Austria      9609

# %%
df1 = df1.drop('indice', axis=1)

# %%
df1.head()
# Out:
#         paises precio_m2
# 4       Monaco     44522
# 5           UK     21179
# 6  Switzerland     13280
# 7       France     12796
# 8      Austria      9609

# %%
#Segunda fuente de CSV

# %%
df2 = pd.read_excel("rental.xlsx","Data")

# %%
df2.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1         NaN  Average rental cost of apartments in European ...        NaN
# 2         NaN  Average monthly rental cost of a furnished one...        NaN
# 3         NaN                                                NaN    Q4 2019
# 4         NaN                                              Paris       1708
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3    Q4 2020
# 4       1803

# %%
df2 = df2.fillna('-')

# %%
df2 = df2.rename(columns={'Unnamed: 0':'indice', 'Unnamed: 1': 'ciudades', 'Unnamed: 2': 'alquiler_2019',
                          'Unnamed: 3': 'alquiler_2020'})

# %%
df2 = df2.drop([0,1,2,3], axis=0)

# %%
df2 = df2.drop('indice', axis=1)

# %%
df2
df2_lst = ["France","UK","Netherlands","Germany","Finland","Netherlands","Netherlands","Netherlands",
           "Spain","Italy","Portugal","Italy","Spain","Germany","Iceland","Germany","Germany","Belgium","Austria","Italy","Spain","Italy"]
df2["paises"]= df2_lst

# %%
df2.head()
# Out:
#     ciudades alquiler_2019 alquiler_2020       paises
# 4      Paris          1708          1803       France
# 5     London          1747          1780           UK
# 6  Amsterdam          1683          1635  Netherlands
# 7     Munich          1525          1451      Germany
# 8   Helsinki          1398          1381      Finland

# %%
dfinal= pd.merge(df1, df2, left_on='paises', right_on='paises')

# %%
dfinal.head()
# Out:
#         paises precio_m2   ciudades alquiler_2019 alquiler_2020
# 0           UK     21179     London          1747          1780
# 1       France     12796      Paris          1708          1803
# 2      Austria      9609     Vienna           971           951
# 3      Finland      8376   Helsinki          1398          1381
# 4  Netherlands      6902  Amsterdam          1683          1635

# %%
backup=dfinal.copy()

# %%
dfinal = dfinal[["paises", "ciudades", "precio_m2", "alquiler_2019", "alquiler_2020"]]

# %%
dfinal
# Out:
#          paises   ciudades precio_m2 alquiler_2019 alquiler_2020
# 0            UK     London     21179          1747          1780
# 1        France      Paris     12796          1708          1803
# 2       Austria     Vienna      9609           971           951
# 3       Finland   Helsinki      8376          1398          1381
# 4   Netherlands  Amsterdam      6902          1683          1635
# 5   Netherlands  Rotterdam      6902          1297          1306
# 6   Netherlands    Utrecht      6902          1289          1304
# 7   Netherlands  The Hague      6902          1212          1255
# 8         Italy      Milan      6589          1180          1141
# 9         Italy       Rome      6589          1114          1110
# 10        Italy   Florence      6589           982           936
# 11        Italy      Turin      6589           876           805
# 12      Germany     Munich      5907          1525          1451
# 13      Germany  Frankfurt      5907          1068          1103
# 14      Germany    Hamburg      5907          1029          1049
# 15      Germany     Berlin      5907          1142           999
# 16        Spain  Barcelona      4978          1249          1179
# 17        Spain     Madrid      4978          1127          1104
# 18        Spain   Valencia      4978           897           838
# 19     Portugal     Lisbon      3830          1109          1121
# 20      Belgium   Brussels      3171           963           972

# %%
#Hacer columna de la variación y variación %

# %%
#Web Scrapping

# %%
from selenium import webdriver

# %%
webdriver.Chrome('driver/chromedriver_mac')
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="c508d4e421c87fa7e1e678486ab582af")>

# %%
PATH ='driver/chromedriver_mac'

url ='https://www.reinisfischer.com/average-monthly-salary-european-union-2020'

# %%
import time

# %%
driver=webdriver.Chrome(PATH)


driver.get(url)

time.sleep(4)

# %%
ndf=driver.find_elements_by_tag_name('td')

# %%
lst_scr=[e.text for e in driver.find_elements_by_tag_name('tr')if len(e.text)> 3][1:]

# %%
df3 = pd.DataFrame([e.split() for e in lst_scr])

# %%
df3.head()
# Out:
#       0           1          2          3        4       5       6     7
# 0  Rank     Country      Gross      Gross   Change     EUR  Change     %
# 1     1     Denmark  €5,179.00  €5,191.00  -€12.00  -0.23%    None  None
# 2     2  Luxembourg  €5,143.00  €4,412.00  €731.00  16.57%    None  None
# 3     3     Germany  €4,035.00  €3,703.00  €332.00   8.97%    None  None
# 4     4     Ireland  €3,867.00  €3,133.00  €734.00  23.43%    None  None

# %%
col=[]
for i in df3.iloc[0]:
    col.append(i)

# %%
df3.columns = col

# %%
#df3.drop([0], axis=0)

# %%
#df1.rename(columns={'0':'indice', 'Unnamed: 1': 'paises', 'Unnamed: 2': 'precio_m2'})

# %%
df3.head()
# Out:
#    Rank     Country      Gross      Gross   Change     EUR  Change     %
# 0  Rank     Country      Gross      Gross   Change     EUR  Change     %
# 1     1     Denmark  €5,179.00  €5,191.00  -€12.00  -0.23%    None  None
# 2     2  Luxembourg  €5,143.00  €4,412.00  €731.00  16.57%    None  None
# 3     3     Germany  €4,035.00  €3,703.00  €332.00   8.97%    None  None
# 4     4     Ireland  €3,867.00  €3,133.00  €734.00  23.43%    None  None

# %%
dframe= pd.merge(dfinal, df3, left_on='paises', right_on='Country')

# %%
dframe = dframe.drop(['Change','%','Rank'], axis=1)

# %%
dframe.head()
# Out:
#         paises   ciudades precio_m2 alquiler_2019 alquiler_2020      Country  \
# 0       France      Paris     12796          1708          1803       France
# 1      Austria     Vienna      9609           971           951      Austria
# 2      Finland   Helsinki      8376          1398          1381      Finland
# 3  Netherlands  Amsterdam      6902          1683          1635  Netherlands
# 4  Netherlands  Rotterdam      6902          1297          1306  Netherlands
#
#        Gross      Gross    EUR
# 0  €3,097.00  €2,957.00  4.73%
# 1  €3,811.00  €3,632.00  4.93%
# 2  €3,380.00  €3,380.00  0.00%
# 3  €2,855.00  €2,855.00  0.00%
# 4  €2,855.00  €2,855.00  0.00%

# %%
dframe.columns = ['paises', 'ciudades', 'precio_m2', 'alquiler_2019', 'alquiler_2020',
       'country', 'gross2019', 'gross2020', 'EUR']

# %%
dframe
# Out:
#          paises   ciudades precio_m2 alquiler_2019 alquiler_2020      country  \
# 0        France      Paris     12796          1708          1803       France
# 1       Austria     Vienna      9609           971           951      Austria
# 2       Finland   Helsinki      8376          1398          1381      Finland
# 3   Netherlands  Amsterdam      6902          1683          1635  Netherlands
# 4   Netherlands  Rotterdam      6902          1297          1306  Netherlands
# 5   Netherlands    Utrecht      6902          1289          1304  Netherlands
# 6   Netherlands  The Hague      6902          1212          1255  Netherlands
# 7         Italy      Milan      6589          1180          1141        Italy
# 8         Italy       Rome      6589          1114          1110        Italy
# 9         Italy   Florence      6589           982           936        Italy
# 10        Italy      Turin      6589           876           805        Italy
# 11      Germany     Munich      5907          1525          1451      Germany
# 12      Germany  Frankfurt      5907          1068          1103      Germany
# 13      Germany    Hamburg      5907          1029          1049      Germany
# 14      Germany     Berlin      5907          1142           999      Germany
# 15        Spain  Barcelona      4978          1249          1179        Spain
# 16        Spain     Madrid      4978          1127          1104        Spain
# 17        Spain   Valencia      4978           897           838        Spain
# 18     Portugal     Lisbon      3830          1109          1121     Portugal
# 19      Belgium   Brussels      3171           963           972      Belgium
#
#     gross2019  gross2020     EUR
# 0   €3,097.00  €2,957.00   4.73%
# 1   €3,811.00  €3,632.00   4.93%
# 2   €3,380.00  €3,380.00   0.00%
# 3   €2,855.00  €2,855.00   0.00%
# 4   €2,855.00  €2,855.00   0.00%
# 5   €2,855.00  €2,855.00   0.00%
# 6   €2,855.00  €2,855.00   0.00%
# 7   €2,442.00  €2,534.00  -3.63%
# 8   €2,442.00  €2,534.00  -3.63%
# 9   €2,442.00  €2,534.00  -3.63%
# 10  €2,442.00  €2,534.00  -3.63%
# 11  €4,035.00  €3,703.00   8.97%
# 12  €4,035.00  €3,703.00   8.97%
# 13  €4,035.00  €3,703.00   8.97%
# 14  €4,035.00  €3,703.00   8.97%
# 15  €2,279.00  €2,189.00   4.11%
# 16  €2,279.00  €2,189.00   4.11%
# 17  €2,279.00  €2,189.00   4.11%
# 18  €1,418.00  €1,158.00  22.45%
# 19  €3,401.00  €3,401.00   0.00%

# %%
#SQL

# %%
import mysql.connector as conn


def crear_db(nombre, user='root', password='Teresita123', check=True):
    
    crea_db=conn.connect(host='localhost', user=user, passwd=password)
    cursor=crea_db.cursor()
    cursor.execute(f'drop database if exists {nombre}')
    cursor.execute(f'create database {nombre}')
    
    print('done. ;)')
    
    if check:
        cursor.execute('show databases')
        for x in cursor:
            print(x)

# %%
crear_db("hulio")
# Out:
# done. ;)
# ('dbase',)
# ('hulio',)
# ('information_schema',)
# ('my_sql',)
# ('mydb',)
# ('mysql',)
# ('performance_schema',)
# ('publications',)
# ('Sharks',)
# ('Sharks.Attacks',)
# ('Sharks_attacks',)
# ('sys',)

# %%
def crear_tabla_desde_df(df, nombre_tabla, nombre_db, user='root', password='Teresita123', check=True, drop=False):
    
    db=conn.connect(host='localhost', user=user, passwd=password, database=nombre_db)
    cursor=db.cursor()
    
    if drop:
        cursor.execute(f'drop table if exists {nombre_tabla}')
    
    tabla=f"create table {nombre_tabla}(id int, {' varchar(200),'.join(df.columns)} varchar(200));"
    print(tabla)
    
    cursor.execute(tabla)
    
    print(f'Hecho, tabla {nombre_tabla} creada. ;)')
    
    if check:
        cursor.execute('show tables')
        for x in cursor:
            print(x)

# %%
crear_tabla_desde_df(dframe, "sonia", "hulio")
# Out:
# create table sonia(id int, paises varchar(200),ciudades varchar(200),precio_m2 varchar(200),alquiler_2019 varchar(200),alquiler_2020 varchar(200),country varchar(200),gross2019 varchar(200),gross2020 varchar(200),EUR varchar(200));
# Hecho, tabla sonia creada. ;)
# ('sonia',)

# %%
def insertar_datos(df, nombre_tabla, nombre_db, user='root', password='Teresita123', check=True):
    
    db=conn.connect(host='localhost', user=user, passwd=password, database=nombre_db)
    cursor=db.cursor()
    
    for i in range(len(df)):
    
        insert_query='insert into {} (id, {}) values {};'\
                     .format(nombre_tabla, ','.join(df.columns), tuple(np.insert(df.iloc[i].values, 0, i)))

        cursor.execute(insert_query)

    db.commit()
    
    print(f'Hecho, datos dentro de tabla {nombre_tabla}. ;)')
    print()
    print(insert_query)

# %%
insertar_datos(dframe,"sonia","hulio")
# Out:
# Hecho, datos dentro de tabla sonia. ;)
#
# insert into sonia (id, paises,ciudades,precio_m2,alquiler_2019,alquiler_2020,country,gross2019,gross2020,EUR) values (19, 'Belgium', 'Brussels', 3171.0, 963, 972, 'Belgium', '€3,401.00', '€3,401.00', '0.00%');

# %%
def leer_sql(query, nombre_tabla, nombre_db, user='root', password='Teresita123'):
    
    db=conn.connect(host='localhost', user=user, passwd=password, database=nombre_db)
    
    data=pd.read_sql(query, db)
    
    return data

# %%
leer_sql(FROM,"sonia","dbase")
query
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-e9c31d154db5> in <module>
# ----> 1 leer_sql(julio,"sonia","dbase")
#
# NameError: name 'julio' is not defined
