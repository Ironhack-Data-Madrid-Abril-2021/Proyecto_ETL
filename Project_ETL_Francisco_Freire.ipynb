# %% [markdown]
# # ETL Project

# %% [markdown]
# Hi again! For this project, one was asked to extract information from at least 3 different sources, using a minimum of 2 different methods and, finally, load a table to SQL

# %% [markdown]
# For this project I'll choose:
# + 1st Pokémon generation (150) and Mew and the 151
#
#
# + Information sources:
#     + Kaggle: extract and csv from there
#     + Pokémon API
#     + Bulbapedia
#
#
# + Methods:
#     + CSV upload
#     + API
#     + Web Scrapping (using Selenium)

# %% [markdown]
# # CSV extracting

# %% [markdown]
# Firstly, let us extract and read a csv file from Kaggle. I've done this already, and you can find the same file in the following link: https://www.kaggle.com/alopez247/pokemon

# %%
import numpy as np

# %%
import pandas as pd

df = pd.read_csv('pokemon_alopez247.csv')

# %%
df.tail(5)
# Out:
#      Number       Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 716     717    Yveltal     Dark  Flying    680  126     131       95     131
# 717     718    Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719    Diancie     Rock   Fairy    600   50     100      150     100
# 719     720      Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721  Volcanion     Fire   Water    600   80     110      120     130
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 716      98  ...     Red      False      NaN  Undiscovered          NaN
# 717      95  ...   Green      False      NaN  Undiscovered          NaN
# 718     150  ...    Pink      False      NaN  Undiscovered          NaN
# 719     130  ...  Purple      False      NaN  Undiscovered          NaN
# 720      90  ...   Brown      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate       Body_Style
# 716             False     5.79     203.0          45        two_wings
# 717             False     5.00     305.0           3  serpentine_body
# 718              True     0.71       8.8           3        head_arms
# 719             False     0.51       9.0           3        head_only
# 720             False     1.70     195.0           3        quadruped
#
# [5 rows x 23 columns]

# %% [markdown]
# I don't need so many Pokémons... I know now the first generation! Let us remove any Pokémon that doesn't belong to this generation, ie, from the #152 Pokémon forward:

# %%
df = df.drop(range(151,721,1))

# %%
df
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 146     147     Dratini   Dragon     NaN    300   41      64       45      50
# 147     148   Dragonair   Dragon     NaN    420   61      84       65      70
# 148     149   Dragonite   Dragon  Flying    600   91     134       95     100
# 149     150      Mewtwo  Psychic     NaN    680  106     110       90     154
# 150     151         Mew  Psychic     NaN    600  100     100      100     100
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 0        65  ...   Green       True    0.875       Monster        Grass
# 1        80  ...   Green       True    0.875       Monster        Grass
# 2       100  ...   Green       True    0.875       Monster        Grass
# 3        50  ...     Red       True    0.875       Monster       Dragon
# 4        65  ...     Red       True    0.875       Monster       Dragon
# ..      ...  ...     ...        ...      ...           ...          ...
# 146      50  ...    Blue       True    0.500       Water_1       Dragon
# 147      70  ...    Blue       True    0.500       Water_1       Dragon
# 148     100  ...   Brown       True    0.500       Water_1       Dragon
# 149      90  ...  Purple      False      NaN  Undiscovered          NaN
# 150     100  ...    Pink      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate       Body_Style
# 0               False     0.71       6.9          45        quadruped
# 1               False     0.99      13.0          45        quadruped
# 2                True     2.01     100.0          45        quadruped
# 3               False     0.61       8.5          45   bipedal_tailed
# 4               False     1.09      19.0          45   bipedal_tailed
# ..                ...      ...       ...         ...              ...
# 146             False     1.80       3.3          45  serpentine_body
# 147             False     3.99      16.5          45  serpentine_body
# 148             False     2.21     210.0          45   bipedal_tailed
# 149              True     2.01     122.0           3   bipedal_tailed
# 150             False     0.41       4.0          45   bipedal_tailed
#
# [151 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 150
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Number            151 non-null    int64
#  1   Name              151 non-null    object
#  2   Type_1            151 non-null    object
#  3   Type_2            67 non-null     object
#  4   Total             151 non-null    int64
#  5   HP                151 non-null    int64
#  6   Attack            151 non-null    int64
#  7   Defense           151 non-null    int64
#  8   Sp_Atk            151 non-null    int64
#  9   Sp_Def            151 non-null    int64
#  10  Speed             151 non-null    int64
#  11  Generation        151 non-null    int64
#  12  isLegendary       151 non-null    bool
#  13  Color             151 non-null    object
#  14  hasGender         151 non-null    bool
#  15  Pr_Male           138 non-null    float64
#  16  Egg_Group_1       151 non-null    object
#  17  Egg_Group_2       40 non-null     object
#  18  hasMegaEvolution  151 non-null    bool
#  19  Height_m          151 non-null    float64
#  20  Weight_kg         151 non-null    float64
#  21  Catch_Rate        151 non-null    int64
#  22  Body_Style        151 non-null    object
# dtypes: bool(3), float64(3), int64(10), object(7)
# memory usage: 25.2+ KB

# %% [markdown]
# I'll do the following changes of the following data set:
#
# + Remove the columns:
#     + Generation: I already know they are all from the 1st generation (Mew might not be, but let us consider he is)
#     + Pr_Male: probability of being male. Not interesting from my point of view (although, I'll leave the column hasGender for curiosity matters:
#
#         df.iloc[:,15]
#
#         0      0.875
#
#         1      0.875
#             ...
#
#         146    0.500
#
#         147    0.500
#
#         Name: Pr_Male, Length: 151, dtype: float64
#
#     + Egg_Group_1
#     + Egg_Group_2
#     + hasMegaEvolution

# %%
df.drop(['Generation', 'Pr_Male', 'Egg_Group_1', 'Egg_Group_2', 'hasMegaEvolution'], axis = 1, inplace = True)

# %%
df.shape #We now have 18 columns!
# Out:
# (151, 18)

# %% [markdown]
# Luckly for us, the columns from our Dataframe are very clean. Let us just lower case them!

# %%
new_columns = [c.lower() for c in df.columns]
df=df.rename(columns={k:v for k,v in zip(df.columns, new_columns)})
df.columns
# Out:
# Index(['number', 'name', 'type_1', 'type_2', 'total', 'hp', 'attack',
#        'defense', 'sp_atk', 'sp_def', 'speed', 'islegendary', 'color',
#        'hasgender', 'height_m', 'weight_kg', 'catch_rate', 'body_style'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 150
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   number       151 non-null    int64
#  1   name         151 non-null    object
#  2   type_1       151 non-null    object
#  3   type_2       67 non-null     object
#  4   total        151 non-null    int64
#  5   hp           151 non-null    int64
#  6   attack       151 non-null    int64
#  7   defense      151 non-null    int64
#  8   sp_atk       151 non-null    int64
#  9   sp_def       151 non-null    int64
#  10  speed        151 non-null    int64
#  11  islegendary  151 non-null    bool
#  12  color        151 non-null    object
#  13  hasgender    151 non-null    bool
#  14  height_m     151 non-null    float64
#  15  weight_kg    151 non-null    float64
#  16  catch_rate   151 non-null    int64
#  17  body_style   151 non-null    object
# dtypes: bool(2), float64(2), int64(9), object(5)
# memory usage: 20.3+ KB

# %% [markdown]
# Inspecting the above information, one could consider replacing the NaN values from the column type_2. It happens that not all Pokémon have 2 types. Therefore, I'll leave as it is for now!

# %% [markdown]
# # API Extracting

# %% [markdown]
# For this one, we should take import the following libraries:

# %%
# !pip install requests
import json
import requests
from pandas.io.json import json_normalize
# Out:
# Requirement already satisfied: requests in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests) (2.10)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# We are going go collecto some qualitative information regarding the Pokémon. For that, we'll use the following API:
#
# https://pokeapi.co/api/v2/pokemon-species/{id or name}/, being id the number of the Pokémon or its name.

# %% [markdown]
# Let's do an example with one Pokémon, and expand it to the 151

# %%
BASE_URL = 'https://pokeapi.co/api/v2/pokemon-species/150/'
results = requests.get(BASE_URL).json()
results.keys()
# Out:
# dict_keys(['base_happiness', 'capture_rate', 'color', 'egg_groups', 'evolution_chain', 'evolves_from_species', 'flavor_text_entries', 'form_descriptions', 'forms_switchable', 'gender_rate', 'genera', 'generation', 'growth_rate', 'habitat', 'has_gender_differences', 'hatch_counter', 'id', 'is_baby', 'is_legendary', 'is_mythical', 'name', 'names', 'order', 'pal_park_encounters', 'pokedex_numbers', 'shape', 'varieties'])

# %%
results['flavor_text_entries'][0]['flavor_text']
# Out:
# 'It was created by\na scientist after\nyears of horrific\x0cgene splicing and\nDNA engineering\nexperiments.'

# %% [markdown]
# So, we want to collect the information contained in the key 'flavor_text_entries' which corresponds to the value 'flavor_text'. We should proceed as follow:

# %%
BASE_URL = 'https://pokeapi.co/api/v2/pokemon-species/'
links = []

for i in range(152):
    if i != 0:
        result = requests.get(BASE_URL + str(i) + '/').json()
        links.append(result)

# %%
links[0].keys()
# Out:
# dict_keys(['base_happiness', 'capture_rate', 'color', 'egg_groups', 'evolution_chain', 'evolves_from_species', 'flavor_text_entries', 'form_descriptions', 'forms_switchable', 'gender_rate', 'genera', 'generation', 'growth_rate', 'habitat', 'has_gender_differences', 'hatch_counter', 'id', 'is_baby', 'is_legendary', 'is_mythical', 'name', 'names', 'order', 'pal_park_encounters', 'pokedex_numbers', 'shape', 'varieties'])

# %%
links[0]['flavor_text_entries'][0]['flavor_text']
# Out:
# 'A strange seed was\nplanted on its\nback at birth.\x0cThe plant sprouts\nand grows with\nthis POKéMON.'

# %%
text = []

for i in range(151):
    text.append(links[i]['flavor_text_entries'][0]['flavor_text'])
text
# Out:
# ['A strange seed was\nplanted on its\nback at birth.\x0cThe plant sprouts\nand grows with\nthis POKéMON.',
#  'When the bulb on\nits back grows\nlarge, it appears\x0cto lose the\nability to stand\non its hind legs.',
#  'The plant blooms\nwhen it is\nabsorbing solar\x0cenergy. It stays\non the move to\nseek sunlight.',
#  'Obviously prefers\nhot places. When\nit rains, steam\x0cis said to spout\nfrom the tip of\nits tail.',
#  'When it swings\nits burning tail,\nit elevates the\x0ctemperature to\nunbearably high\nlevels.',
#  'Spits fire that\nis hot enough to\nmelt boulders.\x0cKnown to cause\nforest fires\nunintentionally.',
#  'Shoots water at\nprey while in the\nwater.\x0cWithdraws into\nits shell when in\ndanger.',
#  'When tapped, this\nPOKéMON will pull\nin its head, but\x0cits tail will\nstill stick out a\nlittle bit.',
#  'It deliberately\nmakes itself heavy\nso it can with\xad\x0cstand the recoil\nof the water jets\nit fires.',
#  'It releases a stench from its red\nantenna to repel enemies. It\ngrows by molting repeatedly.',
#  'This POKéMON is\nvulnerable to\nattack while its\x0cshell is soft,\nexposing its weak\nand tender body.',
#  'In battle, it\nflaps its wings\nat high speed to\x0crelease highly\ntoxic dust into\nthe air.',
#  'Often found in\nforests, eating\nleaves.\x0cIt has a sharp\nvenomous stinger\non its head.',
#  'Almost incapable\nof moving, this\nPOKéMON can only\x0charden its shell\nto protect itself\nfrom predators.',
#  'Flies at high\nspeed and attacks\nusing its large\x0cvenomous stingers\non its forelegs\nand tail.',
#  'A common sight in\nforests and woods.\nIt flaps its\x0cwings at ground\nlevel to kick up\nblinding sand.',
#  'Very protective\nof its sprawling\nterritorial area,\x0cthis POKéMON will\nfiercely peck at\nany intruder.',
#  'When hunting, it\nskims the surface\nof water at high\x0cspeed to pick off\nunwary prey such\nas MAGIKARP.',
#  'Bites anything\nwhen it attacks.\nSmall and very\x0cquick, it is a\ncommon sight in\nmany places.',
#  'It uses its whis\xad\nkers to maintain\nits balance.\x0cIt apparently\nslows down if\nthey are cut off.',
#  'Il est incapable de voler à haute altitude.\nIl se déplace très vite pour protéger\nson territoire.',
#  'With its huge and\nmagnificent wings,\nit can keep aloft\x0cwithout ever\nhaving to land\nfor rest.',
#  'Moves silently\nand stealthily.\nEats the eggs of\x0cbirds, such as\nPIDGEY and\nSPEAROW, whole.',
#  'It is rumored that\nthe ferocious\nwarning markings\x0con its belly\ndiffer from area\nto area.',
#  '最近發表了聚集大量皮卡丘\n來建造發電廠的計畫。',
#  'Its tail discharges electricity into\nthe ground, protecting it from\ngetting shocked.',
#  'Burrows deep\nunderground in\narid locations\x0cfar from water.\nIt only emerges\nto hunt for food.',
#  'Curls up into a\nspiny ball when\nthreatened. It\x0ccan roll while\ncurled up to\nattack or escape.',
#  'Although small,\nits venomous\nbarbs render this\x0cPOKéMON dangerous.\nThe female has\nsmaller horns.',
#  "The female's horn\ndevelops slowly.\nPrefers physical\x0cattacks such as\nclawing and\nbiting.",
#  'Its hard scales\nprovide strong\nprotection. It\x0cuses its hefty\nbulk to execute\npowerful moves.',
#  'Saca las orejas por encima de la hierba para explorar\nel territorio. Le protege su cuerno venenoso.',
#  'An aggressive\nPOKéMON that is\nquick to attack.\x0cThe horn on its\nhead secretes a\npowerful venom.',
#  'One swing of its mighty tail can\nsnap a telephone pole as if it were\na matchstick.',
#  'Its magical and\ncute appeal has\nmany admirers.\x0cIt is rare and\nfound only in\ncertain areas.',
#  'A timid fairy\nPOKéMON that is\nrarely seen. It\x0cwill run and hide\nthe moment it\nsenses people.',
#  'At the time of\nbirth, it has\njust one tail.\x0cThe tail splits\nfrom its tip as\nit grows older.',
#  'Very smart and\nvery vengeful.\nGrabbing one of\x0cits many tails\ncould result in a\n1000-year curse.',
#  'When its huge eyes\nlight up, it sings\na mysteriously\x0csoothing melody\nthat lulls its\nenemies to sleep.',
#  'The body is soft\nand rubbery. When\nangered, it will\x0csuck in air and\ninflate itself to\nan enormous size.',
#  'Forms colonies in\nperpetually dark\nplaces. Uses\x0cultrasonic waves\nto identify and\napproach targets.',
#  'Once it strikes,\nit will not stop\ndraining energy\x0cfrom the victim\neven if it gets\ntoo heavy to fly.',
#  'During the day,\nit keeps its face\nburied in the\x0cground. At night,\nit wanders around\nsowing its seeds.',
#  'It secretes a\nsticky, drool-like\nhoney. Although\x0csweet, it smells\ntoo repulsive to\nget very close.',
#  "It has the world's\nlargest petals.\nWith every step,\x0cthe petals shake\nout heavy clouds\nof toxic pollen.",
#  'Burrows to suck\ntree roots. The\nmushrooms on its\x0cback grow by draw\xad\ning nutrients from\nthe bug host.',
#  'A host-parasite\npair in which the\nparasite mushroom\x0chas taken over the\nhost bug. Prefers\ndamp places.',
#  'Lives in the\nshadows of tall\ntrees where it\x0ceats insects. It\nis attracted by\nlight at night.',
#  'The dust-like\nscales covering\nits wings are\x0ccolor coded to\nindicate the kinds\nof poison it has.',
#  'Lives about one\nyard underground\nwhere it feeds on\x0cplant roots. It\nsometimes appears\nabove ground.',
#  'A team of DIGLETT\ntriplets.\nIt triggers huge\x0cearthquakes by\nburrowing 60 miles\nunderground.',
#  'Es de naturaleza nocturna. Le atraen los objetos\nbrillantes.',
#  'Although its fur\nhas many admirers,\nit is tough to\x0craise as a pet\nbecause of its\nfickle meanness.',
#  'While lulling its\nenemies with its\nvacant look, this\x0cwily POKéMON will\nuse psychokinetic\npowers.',
#  'Often seen swim\xad\nming elegantly by\nlake shores. It\x0cis often mistaken\nfor the Japanese\nmonster, Kappa.',
#  'Extremely quick to\nanger. It could\nbe docile one\x0cmoment then\nthrashing away\nthe next instant.',
#  'Always furious\nand tenacious to\nboot. It will not\x0cabandon chasing\nits quarry until\nit is caught.',
#  'Very protective\nof its territory.\nIt will bark and\x0cbite to repel\nintruders from\nits space.',
#  'A POKéMON that\nhas been admired\nsince the past\x0cfor its beauty.\nIt runs agilely\nas if on wings.',
#  'Its newly grown\nlegs prevent it\nfrom running. It\x0cappears to prefer\nswimming than\ntrying to stand.',
#  'Capable of living\nin or out of\nwater. When out\x0cof water, it\nsweats to keep\nits body slimy.',
#  'An adept swimmer\nat both the front\ncrawl and breast\x0cstroke. Easily\novertakes the best\nhuman swimmers.',
#  'Dieses Pokémon schläft 18 Stunden am Tag.\nBei Gefahr teleportiert es sich in Sicherheit,\nohne dabei aufzuwachen.',
#  'It emits special\nalpha waves from\nits body that\x0cinduce headaches\njust by being\nclose by.',
#  'Its brain can out\xad\nperform a super\xad\ncomputer.\x0cIts intelligence\nquotient is said\nto be 5,000.',
#  'Loves to build\nits muscles.\nIt trains in all\x0cstyles of martial\narts to become\neven stronger.',
#  'Its muscular body\nis so powerful, it\nmust wear a power\x0csave belt to be\nable to regulate\nits motions.',
#  'Using its heavy\nmuscles, it throws\npowerful punches\x0cthat can send the\nvictim clear over\nthe horizon.',
#  'Even though its body is extremely\nskinny, it is blindingly fast\nwhen catching its prey.',
#  'Escupe Polvo Veneno para envenenar al enemigo y,\nluego, lo liquida con Ácido.',
#  'Said to live in\nhuge colonies\ndeep in jungles,\x0calthough no one\nhas ever returned\nfrom there.',
#  'Son corps est principalement composé d’eau.\nSes yeux cristallins projettent d’étranges rayons.',
#  '80개의 촉수를 자유롭게\n움직인다. 찔리면 독이 퍼져\n극심한 고통을 겪게 된다.',
#  'Found in fields\nand mountains.\nMistaking them\x0cfor boulders,\npeople often step\nor trip on them.',
#  'Rolls down slopes\nto move. It rolls\nover any obstacle\x0cwithout slowing\nor changing its\ndirection.',
#  'Its boulder-like\nbody is extremely\nhard. It can\x0ceasily withstand\ndynamite blasts\nwithout damage.',
#  'Its hooves are 10\ntimes harder than\ndiamonds. It can\x0ctrample anything\ncompletely flat\nin little time.',
#  'Very competitive,\nthis POKéMON will\nchase anything\x0cthat moves fast\nin the hopes of\nracing it.',
#  'Incredibly slow\nand dopey. It\ntakes 5 seconds\x0cfor it to feel\npain when under\nattack.',
#  "The SHELLDER that\nis latched onto\nSLOWPOKE's tail\x0cis said to feed\non the host's left\nover scraps.",
#  'Uses anti-gravity\nto stay suspended.\nAppears without\x0cwarning and uses\nTHUNDER WAVE and\nsimilar moves.',
#  'Formed by several\nMAGNEMITEs linked\ntogether. They\x0cfrequently appear\nwhen sunspots\nflare up.',
#  'The sprig of\ngreen onions it\nholds is its\x0cweapon. It is\nused much like a\nmetal sword.',
#  'A bird that makes\nup for its poor\nflying with its\x0cfast foot speed.\nLeaves giant\nfootprints.',
#  'Uses its three\nbrains to execute\ncomplex plans.\x0cWhile two heads\nsleep, one head\nstays awake.',
#  'The protruding\nhorn on its head\nis very hard.\x0cIt is used for\nbashing through\nthick ice.',
#  'Stores thermal\nenergy in its\nbody. Swims at a\x0csteady 8 knots\neven in intensely\ncold waters.',
#  'Appears in filthy\nareas. Thrives by\nsucking up\x0cpolluted sludge\nthat is pumped\nout of factories.',
#  'Thickly covered\nwith a filthy,\nvile sludge. It\x0cis so toxic, even\nits footprints\ncontain poison.',
#  'Its hard shell\nrepels any kind\nof attack.\x0cIt is vulnerable\nonly when its\nshell is open.',
#  'CLOYSTER that live\nin seas with harsh\ntidal currents\x0cgrow large, sharp\nspikes on their\nshells.',
#  'Almost invisible,\nthis gaseous\nPOKéMON cloaks\x0cthe target and\nputs it to sleep\nwithout notice.',
#  'Because of its\nability to slip\nthrough block\x0cwalls, it is said\nto be from an\xad\nother dimension.',
#  'Under a full moon,\nthis POKéMON\nlikes to mimic\x0cthe shadows of\npeople and laugh\nat their fright.',
#  'As it grows, the\nstone portions of\nits body harden\x0cto become similar\nto a diamond, but\ncolored black.',
#  'Puts enemies to\nsleep then eats\ntheir dreams.\x0cOccasionally gets\nsick from eating\nbad dreams.',
#  'When it locks eyes\nwith an enemy, it\nwill use a mix of\x0cPSI moves such as\nHYPNOSIS and\nCONFUSION.',
#  'Its pincers are\nnot only powerful\nweapons, they are\x0cused for balance\nwhen walking\nsideways.',
#  'The large pincer\nhas 10000 hp of\ncrushing power.\x0cHowever, its huge\nsize makes it\nunwieldy to use.',
#  'Usually found in\npower plants.\nEasily mistaken\x0cfor a POKé BALL,\nthey have zapped\nmany people.',
#  'It stores electric\nenergy under very\nhigh pressure.\x0cIt often explodes\nwith little or no\nprovocation.',
#  'Often mistaken\nfor eggs.\nWhen disturbed,\x0cthey quickly\ngather and attack\nin swarms.',
#  'Legend has it that\non rare occasions,\none of its heads\x0cwill drop off and\ncontinue on as an\nEXEGGCUTE.',
#  '死に別れた\u3000母親の\u3000骨を\n頭に\u3000覆っている。寂しいとき\n大声で\u3000泣くという。',
#  '骨に\u3000灯った\u3000呪いの\u3000炎は\nいつまでも\u3000治らない\u3000痛みを\n体と\u3000心に\u3000残すという。',
#  'When in a hurry,\nits legs lengthen\nprogressively.\x0cIt runs smoothly\nwith extra long,\nloping strides.',
#  'While apparently\ndoing nothing, it\nfires punches in\x0clightning fast\nvolleys that are\nimpossible to see.',
#  "Its tongue can be\nextended like a\nchameleon's. It\x0cleaves a tingling\nsensation when it\nlicks enemies.",
#  'Because it stores\nseveral kinds of\ntoxic gases in\x0cits body, it is\nprone to exploding\nwithout warning.',
#  'Where two kinds\nof poison gases\nmeet, 2 KOFFINGs\x0ccan fuse into a\nWEEZING over many\nyears.',
#  'Its massive bones\nare 1000 times\nharder than human\x0cbones. It can\neasily knock a\ntrailer flying.',
#  'Protected by an\narmor-like hide,\nit is capable of\x0cliving in molten\nlava of 3,600\ndegrees.',
#  'A rare and elusive\nPOKéMON that is\nsaid to bring\x0chappiness to those\nwho manage to get\nit.',
#  'The whole body is\nswathed with wide\nvines that are\x0csimilar to sea\xad\nweed. Its vines\nshake as it walks.',
#  "The infant rarely\nventures out of\nits mother's\x0cprotective pouch\nuntil it is 3\nyears old.",
#  'Hace su nido entre los corales. Si se siente en peligro,\nescupe tinta y huye.',
#  'Capable of swim\xad\nming backwards by\nrapidly flapping\x0cits wing-like\npectoral fins and\nstout tail.',
#  'せびれ\u3000むなびれ\u3000おびれが\nゆうがに\u3000たなびくので\nみずのおどりこ\u3000とよばれる。',
#  'In the autumn\nspawning season,\nthey can be seen\x0cswimming power\xad\nfully up rivers\nand creeks.',
#  'An enigmatic\nPOKéMON that can\neffortlessly\x0cregenerate any\nappendage it\nloses in battle.',
#  'Its central core\nglows with the\nseven colors of\x0cthe rainbow. Some\npeople value the\ncore as a gem.',
#  'If interrupted\nwhile it is\nmiming, it will\x0cslap around the\noffender with its\nbroad hands.',
#  'With ninja-like\nagility and speed,\nit can create the\x0cillusion that\nthere is more\nthan one.',
#  'Its cries sound like human speech.\nHowever, it is impossible to tell\nwhat it is trying to say.',
#  'Normally found\nnear power plants,\nthey can wander\x0caway and cause\nmajor blackouts\nin cities.',
#  'Its body always\nburns with an\norange glow that\x0cenables it to\nhide perfectly\namong flames.',
#  'If it fails to\ncrush the victim\nin its pincers,\x0cit will swing it\naround and toss\nit hard.',
#  'When it targets\nan enemy, it\ncharges furiously\x0cwhile whipping its\nbody with its\nlong tails.',
#  'In the distant\npast, it was\nsomewhat stronger\x0cthan the horribly\nweak descendants\nthat exist today.',
#  'Rarely seen in\nthe wild. Huge\nand vicious, it\x0cis capable of\ndestroying entire\ncities in a rage.',
#  'A POKéMON that\nhas been over\xad\nhunted almost to\x0cextinction. It\ncan ferry people\nacross the water.',
#  'It can freely recombine its own cellular structure to\ntransform into other life-forms.',
#  'Its genetic code\nis irregular.\nIt may mutate if\x0cit is exposed to\nradiation from\nelement STONEs.',
#  '수중에서의 생활에 적합한\n몸으로 진화했다.\n물에 녹으면 보이지 않게 된다.',
#  'It accumulates\nnegative ions in\nthe atmosphere to\x0cblast out 10000-\nvolt lightning\nbolts.',
#  'When storing\nthermal energy in\nits body, its\x0ctemperature could\nsoar to over 1600\ndegrees.',
#  'A POKéMON that\nconsists entirely\nof programming\x0ccode. Capable of\nmoving freely in\ncyberspace.',
#  'Although long\nextinct, in rare\ncases, it can be\x0cgenetically\nresurrected from\nfossils.',
#  "Apparently, it\ncracked SHELLDER's\nshell with its\x0csharp fangs and\nsucked out the\ninsides.",
#  'A POKéMON that\nwas resurrected\nfrom a fossil\x0cfound in what was\nonce the ocean\nfloor eons ago.',
#  'Its sleek shape is\nperfect for swim\xad\nming. It slashes\x0cprey with its\nclaws and drains\nthe body fluids.',
#  "A ferocious, pre\xad\nhistoric POKéMON\nthat goes for the\x0cenemy's throat\nwith its serrated\nsaw-like fangs.",
#  'Very lazy. Just\neats and sleeps.\nAs its rotund\x0cbulk builds, it\nbecomes steadily\nmore slothful.',
#  'A legendary bird\nPOKéMON that is\nsaid to appear to\x0cdoomed people who\nare lost in icy\nmountains.',
#  'A legendary bird\nPOKéMON that is\nsaid to appear\x0cfrom clouds while\ndropping enormous\nlightning bolts.',
#  'It is said to be the legendary bird Pokémon of fire.\nEvery flap of its wings creates a dazzling flare\nof flames.',
#  'Long considered a\nmythical POKéMON\nuntil recently\x0cwhen a small\ncolony was found\nliving underwater.',
#  'A mystical POKéMON\nthat exudes a\ngentle aura.\x0cHas the ability\nto change climate\nconditions.',
#  'An extremely\nrarely seen\nmarine POKéMON.\x0cIts intelligence\nis said to match\nthat of humans.',
#  'It was created by\na scientist after\nyears of horrific\x0cgene splicing and\nDNA engineering\nexperiments.',
#  'So rare that it\nis still said to\nbe a mirage by\x0cmany experts. Only\na few people have\nseen it worldwide.']

# %% [markdown]
# Let's clean some weird characters and add them to our current dataframe

# %%
info = [t.replace('\n', ' ').replace('\x0c',' ').replace('\u3000',' ').replace('\xad ', '') for t in text]

# %%
info
# Out:
# ['A strange seed was planted on its back at birth. The plant sprouts and grows with this POKéMON.',
#  'When the bulb on its back grows large, it appears to lose the ability to stand on its hind legs.',
#  'The plant blooms when it is absorbing solar energy. It stays on the move to seek sunlight.',
#  'Obviously prefers hot places. When it rains, steam is said to spout from the tip of its tail.',
#  'When it swings its burning tail, it elevates the temperature to unbearably high levels.',
#  'Spits fire that is hot enough to melt boulders. Known to cause forest fires unintentionally.',
#  'Shoots water at prey while in the water. Withdraws into its shell when in danger.',
#  'When tapped, this POKéMON will pull in its head, but its tail will still stick out a little bit.',
#  'It deliberately makes itself heavy so it can withstand the recoil of the water jets it fires.',
#  'It releases a stench from its red antenna to repel enemies. It grows by molting repeatedly.',
#  'This POKéMON is vulnerable to attack while its shell is soft, exposing its weak and tender body.',
#  'In battle, it flaps its wings at high speed to release highly toxic dust into the air.',
#  'Often found in forests, eating leaves. It has a sharp venomous stinger on its head.',
#  'Almost incapable of moving, this POKéMON can only harden its shell to protect itself from predators.',
#  'Flies at high speed and attacks using its large venomous stingers on its forelegs and tail.',
#  'A common sight in forests and woods. It flaps its wings at ground level to kick up blinding sand.',
#  'Very protective of its sprawling territorial area, this POKéMON will fiercely peck at any intruder.',
#  'When hunting, it skims the surface of water at high speed to pick off unwary prey such as MAGIKARP.',
#  'Bites anything when it attacks. Small and very quick, it is a common sight in many places.',
#  'It uses its whiskers to maintain its balance. It apparently slows down if they are cut off.',
#  'Il est incapable de voler à haute altitude. Il se déplace très vite pour protéger son territoire.',
#  'With its huge and magnificent wings, it can keep aloft without ever having to land for rest.',
#  'Moves silently and stealthily. Eats the eggs of birds, such as PIDGEY and SPEAROW, whole.',
#  'It is rumored that the ferocious warning markings on its belly differ from area to area.',
#  '最近發表了聚集大量皮卡丘 來建造發電廠的計畫。',
#  'Its tail discharges electricity into the ground, protecting it from getting shocked.',
#  'Burrows deep underground in arid locations far from water. It only emerges to hunt for food.',
#  'Curls up into a spiny ball when threatened. It can roll while curled up to attack or escape.',
#  'Although small, its venomous barbs render this POKéMON dangerous. The female has smaller horns.',
#  "The female's horn develops slowly. Prefers physical attacks such as clawing and biting.",
#  'Its hard scales provide strong protection. It uses its hefty bulk to execute powerful moves.',
#  'Saca las orejas por encima de la hierba para explorar el territorio. Le protege su cuerno venenoso.',
#  'An aggressive POKéMON that is quick to attack. The horn on its head secretes a powerful venom.',
#  'One swing of its mighty tail can snap a telephone pole as if it were a matchstick.',
#  'Its magical and cute appeal has many admirers. It is rare and found only in certain areas.',
#  'A timid fairy POKéMON that is rarely seen. It will run and hide the moment it senses people.',
#  'At the time of birth, it has just one tail. The tail splits from its tip as it grows older.',
#  'Very smart and very vengeful. Grabbing one of its many tails could result in a 1000-year curse.',
#  'When its huge eyes light up, it sings a mysteriously soothing melody that lulls its enemies to sleep.',
#  'The body is soft and rubbery. When angered, it will suck in air and inflate itself to an enormous size.',
#  'Forms colonies in perpetually dark places. Uses ultrasonic waves to identify and approach targets.',
#  'Once it strikes, it will not stop draining energy from the victim even if it gets too heavy to fly.',
#  'During the day, it keeps its face buried in the ground. At night, it wanders around sowing its seeds.',
#  'It secretes a sticky, drool-like honey. Although sweet, it smells too repulsive to get very close.',
#  "It has the world's largest petals. With every step, the petals shake out heavy clouds of toxic pollen.",
#  'Burrows to suck tree roots. The mushrooms on its back grow by drawing nutrients from the bug host.',
#  'A host-parasite pair in which the parasite mushroom has taken over the host bug. Prefers damp places.',
#  'Lives in the shadows of tall trees where it eats insects. It is attracted by light at night.',
#  'The dust-like scales covering its wings are color coded to indicate the kinds of poison it has.',
#  'Lives about one yard underground where it feeds on plant roots. It sometimes appears above ground.',
#  'A team of DIGLETT triplets. It triggers huge earthquakes by burrowing 60 miles underground.',
#  'Es de naturaleza nocturna. Le atraen los objetos brillantes.',
#  'Although its fur has many admirers, it is tough to raise as a pet because of its fickle meanness.',
#  'While lulling its enemies with its vacant look, this wily POKéMON will use psychokinetic powers.',
#  'Often seen swimming elegantly by lake shores. It is often mistaken for the Japanese monster, Kappa.',
#  'Extremely quick to anger. It could be docile one moment then thrashing away the next instant.',
#  'Always furious and tenacious to boot. It will not abandon chasing its quarry until it is caught.',
#  'Very protective of its territory. It will bark and bite to repel intruders from its space.',
#  'A POKéMON that has been admired since the past for its beauty. It runs agilely as if on wings.',
#  'Its newly grown legs prevent it from running. It appears to prefer swimming than trying to stand.',
#  'Capable of living in or out of water. When out of water, it sweats to keep its body slimy.',
#  'An adept swimmer at both the front crawl and breast stroke. Easily overtakes the best human swimmers.',
#  'Dieses Pokémon schläft 18 Stunden am Tag. Bei Gefahr teleportiert es sich in Sicherheit, ohne dabei aufzuwachen.',
#  'It emits special alpha waves from its body that induce headaches just by being close by.',
#  'Its brain can outperform a supercomputer. Its intelligence quotient is said to be 5,000.',
#  'Loves to build its muscles. It trains in all styles of martial arts to become even stronger.',
#  'Its muscular body is so powerful, it must wear a power save belt to be able to regulate its motions.',
#  'Using its heavy muscles, it throws powerful punches that can send the victim clear over the horizon.',
#  'Even though its body is extremely skinny, it is blindingly fast when catching its prey.',
#  'Escupe Polvo Veneno para envenenar al enemigo y, luego, lo liquida con Ácido.',
#  'Said to live in huge colonies deep in jungles, although no one has ever returned from there.',
#  'Son corps est principalement composé d’eau. Ses yeux cristallins projettent d’étranges rayons.',
#  '80개의 촉수를 자유롭게 움직인다. 찔리면 독이 퍼져 극심한 고통을 겪게 된다.',
#  'Found in fields and mountains. Mistaking them for boulders, people often step or trip on them.',
#  'Rolls down slopes to move. It rolls over any obstacle without slowing or changing its direction.',
#  'Its boulder-like body is extremely hard. It can easily withstand dynamite blasts without damage.',
#  'Its hooves are 10 times harder than diamonds. It can trample anything completely flat in little time.',
#  'Very competitive, this POKéMON will chase anything that moves fast in the hopes of racing it.',
#  'Incredibly slow and dopey. It takes 5 seconds for it to feel pain when under attack.',
#  "The SHELLDER that is latched onto SLOWPOKE's tail is said to feed on the host's left over scraps.",
#  'Uses anti-gravity to stay suspended. Appears without warning and uses THUNDER WAVE and similar moves.',
#  'Formed by several MAGNEMITEs linked together. They frequently appear when sunspots flare up.',
#  'The sprig of green onions it holds is its weapon. It is used much like a metal sword.',
#  'A bird that makes up for its poor flying with its fast foot speed. Leaves giant footprints.',
#  'Uses its three brains to execute complex plans. While two heads sleep, one head stays awake.',
#  'The protruding horn on its head is very hard. It is used for bashing through thick ice.',
#  'Stores thermal energy in its body. Swims at a steady 8 knots even in intensely cold waters.',
#  'Appears in filthy areas. Thrives by sucking up polluted sludge that is pumped out of factories.',
#  'Thickly covered with a filthy, vile sludge. It is so toxic, even its footprints contain poison.',
#  'Its hard shell repels any kind of attack. It is vulnerable only when its shell is open.',
#  'CLOYSTER that live in seas with harsh tidal currents grow large, sharp spikes on their shells.',
#  'Almost invisible, this gaseous POKéMON cloaks the target and puts it to sleep without notice.',
#  'Because of its ability to slip through block walls, it is said to be from another dimension.',
#  'Under a full moon, this POKéMON likes to mimic the shadows of people and laugh at their fright.',
#  'As it grows, the stone portions of its body harden to become similar to a diamond, but colored black.',
#  'Puts enemies to sleep then eats their dreams. Occasionally gets sick from eating bad dreams.',
#  'When it locks eyes with an enemy, it will use a mix of PSI moves such as HYPNOSIS and CONFUSION.',
#  'Its pincers are not only powerful weapons, they are used for balance when walking sideways.',
#  'The large pincer has 10000 hp of crushing power. However, its huge size makes it unwieldy to use.',
#  'Usually found in power plants. Easily mistaken for a POKé BALL, they have zapped many people.',
#  'It stores electric energy under very high pressure. It often explodes with little or no provocation.',
#  'Often mistaken for eggs. When disturbed, they quickly gather and attack in swarms.',
#  'Legend has it that on rare occasions, one of its heads will drop off and continue on as an EXEGGCUTE.',
#  '死に別れた 母親の 骨を 頭に 覆っている。寂しいとき 大声で 泣くという。',
#  '骨に 灯った 呪いの 炎は いつまでも 治らない 痛みを 体と 心に 残すという。',
#  'When in a hurry, its legs lengthen progressively. It runs smoothly with extra long, loping strides.',
#  'While apparently doing nothing, it fires punches in lightning fast volleys that are impossible to see.',
#  "Its tongue can be extended like a chameleon's. It leaves a tingling sensation when it licks enemies.",
#  'Because it stores several kinds of toxic gases in its body, it is prone to exploding without warning.',
#  'Where two kinds of poison gases meet, 2 KOFFINGs can fuse into a WEEZING over many years.',
#  'Its massive bones are 1000 times harder than human bones. It can easily knock a trailer flying.',
#  'Protected by an armor-like hide, it is capable of living in molten lava of 3,600 degrees.',
#  'A rare and elusive POKéMON that is said to bring happiness to those who manage to get it.',
#  'The whole body is swathed with wide vines that are similar to seaweed. Its vines shake as it walks.',
#  "The infant rarely ventures out of its mother's protective pouch until it is 3 years old.",
#  'Hace su nido entre los corales. Si se siente en peligro, escupe tinta y huye.',
#  'Capable of swimming backwards by rapidly flapping its wing-like pectoral fins and stout tail.',
#  'せびれ むなびれ おびれが ゆうがに たなびくので みずのおどりこ とよばれる。',
#  'In the autumn spawning season, they can be seen swimming powerfully up rivers and creeks.',
#  'An enigmatic POKéMON that can effortlessly regenerate any appendage it loses in battle.',
#  'Its central core glows with the seven colors of the rainbow. Some people value the core as a gem.',
#  'If interrupted while it is miming, it will slap around the offender with its broad hands.',
#  'With ninja-like agility and speed, it can create the illusion that there is more than one.',
#  'Its cries sound like human speech. However, it is impossible to tell what it is trying to say.',
#  'Normally found near power plants, they can wander away and cause major blackouts in cities.',
#  'Its body always burns with an orange glow that enables it to hide perfectly among flames.',
#  'If it fails to crush the victim in its pincers, it will swing it around and toss it hard.',
#  'When it targets an enemy, it charges furiously while whipping its body with its long tails.',
#  'In the distant past, it was somewhat stronger than the horribly weak descendants that exist today.',
#  'Rarely seen in the wild. Huge and vicious, it is capable of destroying entire cities in a rage.',
#  'A POKéMON that has been overhunted almost to extinction. It can ferry people across the water.',
#  'It can freely recombine its own cellular structure to transform into other life-forms.',
#  'Its genetic code is irregular. It may mutate if it is exposed to radiation from element STONEs.',
#  '수중에서의 생활에 적합한 몸으로 진화했다. 물에 녹으면 보이지 않게 된다.',
#  'It accumulates negative ions in the atmosphere to blast out 10000- volt lightning bolts.',
#  'When storing thermal energy in its body, its temperature could soar to over 1600 degrees.',
#  'A POKéMON that consists entirely of programming code. Capable of moving freely in cyberspace.',
#  'Although long extinct, in rare cases, it can be genetically resurrected from fossils.',
#  "Apparently, it cracked SHELLDER's shell with its sharp fangs and sucked out the insides.",
#  'A POKéMON that was resurrected from a fossil found in what was once the ocean floor eons ago.',
#  'Its sleek shape is perfect for swimming. It slashes prey with its claws and drains the body fluids.',
#  "A ferocious, prehistoric POKéMON that goes for the enemy's throat with its serrated saw-like fangs.",
#  'Very lazy. Just eats and sleeps. As its rotund bulk builds, it becomes steadily more slothful.',
#  'A legendary bird POKéMON that is said to appear to doomed people who are lost in icy mountains.',
#  'A legendary bird POKéMON that is said to appear from clouds while dropping enormous lightning bolts.',
#  'It is said to be the legendary bird Pokémon of fire. Every flap of its wings creates a dazzling flare of flames.',
#  'Long considered a mythical POKéMON until recently when a small colony was found living underwater.',
#  'A mystical POKéMON that exudes a gentle aura. Has the ability to change climate conditions.',
#  'An extremely rarely seen marine POKéMON. Its intelligence is said to match that of humans.',
#  'It was created by a scientist after years of horrific gene splicing and DNA engineering experiments.',
#  'So rare that it is still said to be a mirage by many experts. Only a few people have seen it worldwide.']

# %%
backup = df.copy()

# %%
df['information'] = info

# %%
df.head(5)
# Out:
#    number        name type_1  type_2  total  hp  attack  defense  sp_atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    sp_def  speed  islegendary  color  hasgender  height_m  weight_kg  \
# 0      65     45        False  Green       True      0.71        6.9
# 1      80     60        False  Green       True      0.99       13.0
# 2     100     80        False  Green       True      2.01      100.0
# 3      50     65        False    Red       True      0.61        8.5
# 4      65     80        False    Red       True      1.09       19.0
#
#    catch_rate      body_style  \
# 0          45       quadruped
# 1          45       quadruped
# 2          45       quadruped
# 3          45  bipedal_tailed
# 4          45  bipedal_tailed
#
#                                          information
# 0  A strange seed was planted on its back at birt...
# 1  When the bulb on its back grows large, it appe...
# 2  The plant blooms when it is absorbing solar en...
# 3  Obviously prefers hot places. When it rains, s...
# 4  When it swings its burning tail, it elevates t...

# %% [markdown]
# Done! Let us add the apis per Pokémon as well:

# %%
BASE_URL = 'https://pokeapi.co/api/v2/'
midpoint = 'pokemon/'
apis = []

for i in range(152):
    if i != 0:
        api = BASE_URL + midpoint + str(i)
        apis.append(api)
apis
# Out:
# ['https://pokeapi.co/api/v2/pokemon/1',
#  'https://pokeapi.co/api/v2/pokemon/2',
#  'https://pokeapi.co/api/v2/pokemon/3',
#  'https://pokeapi.co/api/v2/pokemon/4',
#  'https://pokeapi.co/api/v2/pokemon/5',
#  'https://pokeapi.co/api/v2/pokemon/6',
#  'https://pokeapi.co/api/v2/pokemon/7',
#  'https://pokeapi.co/api/v2/pokemon/8',
#  'https://pokeapi.co/api/v2/pokemon/9',
#  'https://pokeapi.co/api/v2/pokemon/10',
#  'https://pokeapi.co/api/v2/pokemon/11',
#  'https://pokeapi.co/api/v2/pokemon/12',
#  'https://pokeapi.co/api/v2/pokemon/13',
#  'https://pokeapi.co/api/v2/pokemon/14',
#  'https://pokeapi.co/api/v2/pokemon/15',
#  'https://pokeapi.co/api/v2/pokemon/16',
#  'https://pokeapi.co/api/v2/pokemon/17',
#  'https://pokeapi.co/api/v2/pokemon/18',
#  'https://pokeapi.co/api/v2/pokemon/19',
#  'https://pokeapi.co/api/v2/pokemon/20',
#  'https://pokeapi.co/api/v2/pokemon/21',
#  'https://pokeapi.co/api/v2/pokemon/22',
#  'https://pokeapi.co/api/v2/pokemon/23',
#  'https://pokeapi.co/api/v2/pokemon/24',
#  'https://pokeapi.co/api/v2/pokemon/25',
#  'https://pokeapi.co/api/v2/pokemon/26',
#  'https://pokeapi.co/api/v2/pokemon/27',
#  'https://pokeapi.co/api/v2/pokemon/28',
#  'https://pokeapi.co/api/v2/pokemon/29',
#  'https://pokeapi.co/api/v2/pokemon/30',
#  'https://pokeapi.co/api/v2/pokemon/31',
#  'https://pokeapi.co/api/v2/pokemon/32',
#  'https://pokeapi.co/api/v2/pokemon/33',
#  'https://pokeapi.co/api/v2/pokemon/34',
#  'https://pokeapi.co/api/v2/pokemon/35',
#  'https://pokeapi.co/api/v2/pokemon/36',
#  'https://pokeapi.co/api/v2/pokemon/37',
#  'https://pokeapi.co/api/v2/pokemon/38',
#  'https://pokeapi.co/api/v2/pokemon/39',
#  'https://pokeapi.co/api/v2/pokemon/40',
#  'https://pokeapi.co/api/v2/pokemon/41',
#  'https://pokeapi.co/api/v2/pokemon/42',
#  'https://pokeapi.co/api/v2/pokemon/43',
#  'https://pokeapi.co/api/v2/pokemon/44',
#  'https://pokeapi.co/api/v2/pokemon/45',
#  'https://pokeapi.co/api/v2/pokemon/46',
#  'https://pokeapi.co/api/v2/pokemon/47',
#  'https://pokeapi.co/api/v2/pokemon/48',
#  'https://pokeapi.co/api/v2/pokemon/49',
#  'https://pokeapi.co/api/v2/pokemon/50',
#  'https://pokeapi.co/api/v2/pokemon/51',
#  'https://pokeapi.co/api/v2/pokemon/52',
#  'https://pokeapi.co/api/v2/pokemon/53',
#  'https://pokeapi.co/api/v2/pokemon/54',
#  'https://pokeapi.co/api/v2/pokemon/55',
#  'https://pokeapi.co/api/v2/pokemon/56',
#  'https://pokeapi.co/api/v2/pokemon/57',
#  'https://pokeapi.co/api/v2/pokemon/58',
#  'https://pokeapi.co/api/v2/pokemon/59',
#  'https://pokeapi.co/api/v2/pokemon/60',
#  'https://pokeapi.co/api/v2/pokemon/61',
#  'https://pokeapi.co/api/v2/pokemon/62',
#  'https://pokeapi.co/api/v2/pokemon/63',
#  'https://pokeapi.co/api/v2/pokemon/64',
#  'https://pokeapi.co/api/v2/pokemon/65',
#  'https://pokeapi.co/api/v2/pokemon/66',
#  'https://pokeapi.co/api/v2/pokemon/67',
#  'https://pokeapi.co/api/v2/pokemon/68',
#  'https://pokeapi.co/api/v2/pokemon/69',
#  'https://pokeapi.co/api/v2/pokemon/70',
#  'https://pokeapi.co/api/v2/pokemon/71',
#  'https://pokeapi.co/api/v2/pokemon/72',
#  'https://pokeapi.co/api/v2/pokemon/73',
#  'https://pokeapi.co/api/v2/pokemon/74',
#  'https://pokeapi.co/api/v2/pokemon/75',
#  'https://pokeapi.co/api/v2/pokemon/76',
#  'https://pokeapi.co/api/v2/pokemon/77',
#  'https://pokeapi.co/api/v2/pokemon/78',
#  'https://pokeapi.co/api/v2/pokemon/79',
#  'https://pokeapi.co/api/v2/pokemon/80',
#  'https://pokeapi.co/api/v2/pokemon/81',
#  'https://pokeapi.co/api/v2/pokemon/82',
#  'https://pokeapi.co/api/v2/pokemon/83',
#  'https://pokeapi.co/api/v2/pokemon/84',
#  'https://pokeapi.co/api/v2/pokemon/85',
#  'https://pokeapi.co/api/v2/pokemon/86',
#  'https://pokeapi.co/api/v2/pokemon/87',
#  'https://pokeapi.co/api/v2/pokemon/88',
#  'https://pokeapi.co/api/v2/pokemon/89',
#  'https://pokeapi.co/api/v2/pokemon/90',
#  'https://pokeapi.co/api/v2/pokemon/91',
#  'https://pokeapi.co/api/v2/pokemon/92',
#  'https://pokeapi.co/api/v2/pokemon/93',
#  'https://pokeapi.co/api/v2/pokemon/94',
#  'https://pokeapi.co/api/v2/pokemon/95',
#  'https://pokeapi.co/api/v2/pokemon/96',
#  'https://pokeapi.co/api/v2/pokemon/97',
#  'https://pokeapi.co/api/v2/pokemon/98',
#  'https://pokeapi.co/api/v2/pokemon/99',
#  'https://pokeapi.co/api/v2/pokemon/100',
#  'https://pokeapi.co/api/v2/pokemon/101',
#  'https://pokeapi.co/api/v2/pokemon/102',
#  'https://pokeapi.co/api/v2/pokemon/103',
#  'https://pokeapi.co/api/v2/pokemon/104',
#  'https://pokeapi.co/api/v2/pokemon/105',
#  'https://pokeapi.co/api/v2/pokemon/106',
#  'https://pokeapi.co/api/v2/pokemon/107',
#  'https://pokeapi.co/api/v2/pokemon/108',
#  'https://pokeapi.co/api/v2/pokemon/109',
#  'https://pokeapi.co/api/v2/pokemon/110',
#  'https://pokeapi.co/api/v2/pokemon/111',
#  'https://pokeapi.co/api/v2/pokemon/112',
#  'https://pokeapi.co/api/v2/pokemon/113',
#  'https://pokeapi.co/api/v2/pokemon/114',
#  'https://pokeapi.co/api/v2/pokemon/115',
#  'https://pokeapi.co/api/v2/pokemon/116',
#  'https://pokeapi.co/api/v2/pokemon/117',
#  'https://pokeapi.co/api/v2/pokemon/118',
#  'https://pokeapi.co/api/v2/pokemon/119',
#  'https://pokeapi.co/api/v2/pokemon/120',
#  'https://pokeapi.co/api/v2/pokemon/121',
#  'https://pokeapi.co/api/v2/pokemon/122',
#  'https://pokeapi.co/api/v2/pokemon/123',
#  'https://pokeapi.co/api/v2/pokemon/124',
#  'https://pokeapi.co/api/v2/pokemon/125',
#  'https://pokeapi.co/api/v2/pokemon/126',
#  'https://pokeapi.co/api/v2/pokemon/127',
#  'https://pokeapi.co/api/v2/pokemon/128',
#  'https://pokeapi.co/api/v2/pokemon/129',
#  'https://pokeapi.co/api/v2/pokemon/130',
#  'https://pokeapi.co/api/v2/pokemon/131',
#  'https://pokeapi.co/api/v2/pokemon/132',
#  'https://pokeapi.co/api/v2/pokemon/133',
#  'https://pokeapi.co/api/v2/pokemon/134',
#  'https://pokeapi.co/api/v2/pokemon/135',
#  'https://pokeapi.co/api/v2/pokemon/136',
#  'https://pokeapi.co/api/v2/pokemon/137',
#  'https://pokeapi.co/api/v2/pokemon/138',
#  'https://pokeapi.co/api/v2/pokemon/139',
#  'https://pokeapi.co/api/v2/pokemon/140',
#  'https://pokeapi.co/api/v2/pokemon/141',
#  'https://pokeapi.co/api/v2/pokemon/142',
#  'https://pokeapi.co/api/v2/pokemon/143',
#  'https://pokeapi.co/api/v2/pokemon/144',
#  'https://pokeapi.co/api/v2/pokemon/145',
#  'https://pokeapi.co/api/v2/pokemon/146',
#  'https://pokeapi.co/api/v2/pokemon/147',
#  'https://pokeapi.co/api/v2/pokemon/148',
#  'https://pokeapi.co/api/v2/pokemon/149',
#  'https://pokeapi.co/api/v2/pokemon/150',
#  'https://pokeapi.co/api/v2/pokemon/151']

# %%
df['api'] = apis

# %%
df.head()
# Out:
#    number        name type_1  type_2  total  hp  attack  defense  sp_atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    sp_def  speed  islegendary  color  hasgender  height_m  weight_kg  \
# 0      65     45        False  Green       True      0.71        6.9
# 1      80     60        False  Green       True      0.99       13.0
# 2     100     80        False  Green       True      2.01      100.0
# 3      50     65        False    Red       True      0.61        8.5
# 4      65     80        False    Red       True      1.09       19.0
#
#    catch_rate      body_style  \
# 0          45       quadruped
# 1          45       quadruped
# 2          45       quadruped
# 3          45  bipedal_tailed
# 4          45  bipedal_tailed
#
#                                          information  \
# 0  A strange seed was planted on its back at birt...
# 1  When the bulb on its back grows large, it appe...
# 2  The plant blooms when it is absorbing solar en...
# 3  Obviously prefers hot places. When it rains, s...
# 4  When it swings its burning tail, it elevates t...
#
#                                    api
# 0  https://pokeapi.co/api/v2/pokemon/1
# 1  https://pokeapi.co/api/v2/pokemon/2
# 2  https://pokeapi.co/api/v2/pokemon/3
# 3  https://pokeapi.co/api/v2/pokemon/4
# 4  https://pokeapi.co/api/v2/pokemon/5

# %% [markdown]
# Success! Let's proceed with some web scraping

# %% [markdown]
# # Web Scraping using Selenium

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from selenium) (1.26.4)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
import requests

# %%
PATH='chromedriver.exe'

# %% [markdown]
# We will extract information from wikipedia. Thus, one should consider the beloow url:

# %%
url = 'https://en.wikipedia.org/wiki/List_of_generation_I_Pok%C3%A9mon'

# %%
driver=webdriver.Chrome(PATH)
driver.get(url)

# %%
table=driver.find_element_by_xpath('//*[@id="mw-content-text"]/div[1]/table[2]')
table=table.find_element_by_tag_name('tbody')
rows=table.find_elements_by_tag_name('tr')
elements=[[e.text for e in r.find_elements_by_tag_name('td')] for r in rows]
elements
# Out:
# [['1',
#   'Grass',
#   'Poison',
#   'Ivysaur (#002)',
#   'Reception to Bulbasaur has been largely positive and it often appears in "top Pokémon lists".[3][4] Its English name is a portmanteau of "bulb" and "dinosaur".[5] It shares its category with Ivysaur, Venusaur and Sunkern. They are all known as the Seed Pokémon.'],
#  ['2',
#   'Grass',
#   'Poison',
#   'Venusaur (#003)',
#   'Playable character in Super Smash Bros. Brawl and Super Smash Bros. Ultimate as a part of the "Pokémon Trainer" fighter. Its English name is a portmanteau of "ivy" and "dinosaur".[6]'],
#  ['3',
#   'Grass',
#   'Poison',
#   'Mega Evolution',
#   '[Gigantamax] Its English name is a portmanteau of "Venus" (relating to the Venus flytrap) and "dinosaur". It is the mascot of Pokémon Green and LeafGreen.[7] It is based on the Pareiasaur.'],
#  ['4',
#   'Fire',
#   'Charmeleon (#005)',
#   'Charmander is a bipedal, salamander-like creature with a flame at the tip of its tail. Its English name is a portmanteau of "char" and "salamander".[8]'],
#  ['5',
#   'Fire',
#   'Charizard (#006)',
#   'Charmeleon shares a nearly identical design to Charmander, though is larger in stature. Its English name is a portmanteau of "char" and "chameleon".[9]'],
#  ['6',
#   'Fire',
#   'Flying',
#   'Two Mega Evolutions',
#   '[Gigantamax] Playable character as a part of the "Pokémon Trainer" fighter in Super Smash Bros. Brawl and Super Smash Bros. Ultimate, as well as a standalone fighter in Super Smash Bros. for Nintendo 3DS and Wii U. Its English name is a portmanteau of "char" and "lizard".[10] Its Gigantamax Form has literal fire for wings and has fire coming out of its body. Mascot of Pokémon Red and FireRed.'],
#  ['7',
#   'Water',
#   'Wartortle (#008)',
#   'Playable character in Super Smash Bros. Brawl and Super Smash Bros. Ultimate as a part of the "Pokémon Trainer" fighter. Its English name is a portmanteau of "squirt" and "turtle".[11]'],
#  ['8',
#   'Water',
#   'Blastoise (#009)',
#   'Its English name is a portmanteau of "war", "tortoise" and "turtle".[12]'],
#  ['9',
#   'Water',
#   'Mega Evolution',
#   '[Gigantamax] Its English name is a portmanteau of "blast" and "tortoise". Mascot of Pokémon Blue.[13]In early stages of Red and Green\'s development, Blastoise was originally called "Caravaggio", which is believed to be a reference to the Teenage Mutant Ninja Turtles franchise.'],
#  ['10',
#   'Bug',
#   'Metapod (#011)',
#   'To avoid predators, it releases an odor that makes bird Pokémon think twice about going after it.'],
#  ['11',
#   'Bug',
#   'Butterfree (#012)',
#   'It tries to move as little as possible because if its fragile body broke, its liquid guts would spill out, killing it.'],
#  ['12',
#   'Bug',
#   'Flying',
#   'End of evolution',
#   '[Gigantamax] If you put pollen out of your window, a Butterfree will come to you. A Gigantamaxed Butterfree can grow a tremendous size with huge light blue wings.'],
#  ['13',
#   'Bug',
#   'Poison',
#   'Kakuna (#014)',
#   'Its stinger is poisonous so if it finds itself against a foe, it can protect itself for a while.'],
#  ['14',
#   'Bug',
#   'Poison',
#   'Beedrill (#015)',
#   "Similar to Metapod, it can't really move because it is melting its own body to evolve."],
#  ['15',
#   'Bug',
#   'Poison',
#   'Mega Evolution',
#   'Never go near a Beedrill nest because every Beedrill in the nest will angrily swarm you and sting you repeatedly, which is poisonous as well.'],
#  ['16',
#   'Normal',
#   'Flying',
#   'Pidgeotto (#017)',
#   'The common bird of Kanto, Pidgey is a bird that will go after bug Pokémon until it scurries away.'],
#  ['17',
#   'Normal',
#   'Flying',
#   'Pidgeot (#018)',
#   'Pidgeotto was the second Pokémon that Ash Ketchum caught on his journey in the anime.'],
#  ['18',
#   'Normal',
#   'Flying',
#   'Mega Evolution',
#   'A lot of Trainers choose Pidgeot as their Pokémon because of the striking beautiful feathers it has.'],
#  ['19',
#   'Normal',
#   'Raticate (#020)',
#   'Criticized as a "filthy rodent" by GamesRadar and "rubbish" by the Official Nintendo Magazine.[14][15] Its teeth grow very long over time, so it has to gnaw on logs, houses, telephone poles and more so it can be quite a pest at times.'],
#  ['20',
#   'Normal',
#   'End of evolution',
#   'Raticate is a rodent that commands the groups of Rattatas to get it food. Like Rattata, it too needs to whittle its teeth down but it does so on harder objects like steel, wood, rocks, fruit, and more.'],
#  ['21',
#   'Normal',
#   'Flying',
#   'Fearow (#022)',
#   'Eats bugs in grassy areas. It has to flap its short wings at high speed to stay airborne.'],
#  ['22',
#   'Normal',
#   'Flying',
#   'End of evolution',
#   'Its English name is a portmanteau of "fear" and "sparrow".'],
#  ['23',
#   'Poison',
#   'Arbok (#024)',
#   "Its English name is “snake” spelled backwards. Ekans likes to coil itself because if it gets attacked while sleeping, it's all ready to strike at them."],
#  ['24',
#   'Poison',
#   'End of evolution',
#   'Belonged to Jessie, a member of Team Rocket, for the Kanto, Johto, and a small portion of the Advanced Generation series of the Pokémon anime. The pattern on its chest is different everywhere. It is hard to escape from its coil because its muscles are so strong. Even though its name is Arbok, what it pronounces is "Char-bok". Its name backwards is kobra, which is pronounced the same as cobra'],
#  ['25',
#   'Electric',
#   'Raichu (#026)',
#   "[Gigantamax] Mascot of the Pokémon franchise, as well as Pokémon Yellow and Let's Go, Pikachu! Also playable in every Super Smash Bros. game to date. Gigantamax Pikachu looks like its old sprite from Red and Blue with a glowing whitish tail. It raises its tail to check its surroundings and it sometimes gets struck by lightning in that pose. If Pikachu sees something new, it'll shock it with electricity. When you see blackened marks on the ground, Pikachu mistook its electrical power."],
#  ['26',
#   'Electric',
#   'End of evolution',
#   'Raichu has an Alola Form that is an Electric/Psychic Type. It was originally intended for Raichu to have an evolution named Gorochu, but it was scrapped due to balance issues.'],
#  ['27',
#   'Ground',
#   'Sandslash (#028)',
#   'Sandshrew has an Alola Form that is a Steel/Ice Type. Based on the Chinese pangolin, Sandshrew is known to curl into a ball to defend itself similar to volvation seen in animals.'],
#  ['28',
#   'Ground',
#   'End of evolution',
#   'Sandslash is a pangolin-like Pokémon Curls up into a spiny ball when threatened. It can roll while curled up to attack or escape. Sandslash has an Alola Form that is a Steel/Ice Type.'],
#  ['29',
#   'Poison',
#   'Nidorina (#030)',
#   "It is related to the Nidoran♂ line, and can produce Eggs that contain either Nidoran♀ or Nidoran♂. However, it is the only one of its line that can breed, as Nidorina and Nidoqueen are part of the Undiscovered Egg Group. Both Nidoran's, Nidorina, Nidorino, Poipole, and Naganadel are known as the Poison Pin Pokémon."],
#  ['30',
#   'Poison',
#   'Nidoqueen (#031)',
#   "When it's with its friends and family, it doesn't have its toxic horn out. As soon as danger appears, it is ready to fight."],
#  ['31',
#   'Poison',
#   'Ground',
#   'End of evolution',
#   'When protecting its young, it gains more strength than normal. Its hide is so strong, not much can hurt it.'],
#  ['32', 'Poison', 'Nidorino (#033)', ''],
#  ['33', 'Poison', 'Nidoking (#034)', ''],
#  ['34',
#   'Poison',
#   'Ground',
#   'End of evolution',
#   'Based on Baragon from the Godzilla franchise, It usually fights for the family if its offspring are in trouble.'],
#  ['35',
#   'Fairy[nb 2]',
#   'Clefable (#036)',
#   "Originally proposed to be joint mascot of the Pokémon franchise alongside Pikachu, but was quickly overshadowed by the latter's popularity[16]"],
#  ['36',
#   'Fairy[nb 2]',
#   'End of evolution',
#   'Clefairy evolves into Clefable when coming contact with a moon stone'],
#  ['37',
#   'Fire',
#   'Ninetales (#038)',
#   'When a Vulpix is born, it only has one white tail that splits into 6 if it gets plenty of love from its Trainer or mother.'],
#  ['38',
#   'Fire',
#   'End of evolution',
#   'Designs inspired by the nine-tailed fox of East Asian myth.[17]'],
#  ['39',
#   'Normal',
#   'Fairy[nb 2]',
#   'Wigglytuff (#040)',
#   'Playable in every Super Smash Bros. game to date.'],
#  ['40',
#   'Normal',
#   'Fairy[nb 2]',
#   'End of evolution',
#   "It doesn't care if its large eyes gets dust or dirt in them because its eyes are covered in a thin layer of fluid."],
#  ['41',
#   'Poison',
#   'Flying',
#   'Golbat (#042)',
#   'It uses echolocation because it has no eyes.'],
#  ['42',
#   'Poison',
#   'Flying',
#   'Crobat (#169)',
#   "Golbat loves to drink blood, however it sometimes drinks so much that it can't fly."],
#  ['43',
#   'Grass',
#   'Poison',
#   'Gloom (#044)',
#   'It buries itself in the soil to absorb the nutrients. the more water it drinks, the glossier it becomes.'],
#  ['44',
#   'Grass',
#   'Poison',
#   'Vileplume (#045)\nBellossom (#182)',
#   "If it senses danger around it, it produces a horrific stench from the leaves on its head. If there isn't, it's fine and the stench goes away."],
#  ['45',
#   'Grass',
#   'Poison',
#   'End of evolution',
#   "Tour guides always say not to go up to any flower in the jungle, no matter how beautiful is because of this reason: it might just be a Vileplume which can spread toxic spores that will leave you sick for days. Vileplume is based on the Rafflesia, the world's smelliest flower."],
#  ['46',
#   'Bug',
#   'Grass',
#   'Parasect (#047)',
#   "When a Paras eats, its body isn't getting most of the nutrients, the mushrooms on its back are. Those mushrooms can also be used for medicinal purposes."],
#  ['47',
#   'Bug',
#   'Grass',
#   'End of evolution',
#   'It hollows out trees to absorb its energy. When the tree dies, it will move on to the next. The mushroom has essentially killed it leaving its host to forage for it.'],
#  ['48', 'Bug', 'Poison', 'Venomoth (#049)', ''],
#  ['49', 'Bug', 'Poison', 'End of evolution', ''],
#  ['50',
#   'Ground',
#   'Dugtrio (#051)',
#   'Farmers like to use Digletts to plow the soil for crops to grow plentifully.'],
#  ['51', 'Ground', 'End of evolution', ''],
#  ['52',
#   'Normal',
#   'Persian (#053)',
#   "[Gigantamax] Reoccurring member of Team Rocket in the Pokémon anime series, Meowth loves anything shiny and will steal it if it can. Murkrow and Meowth will loot each other's stash all the time. Gigantamax Meowth is a tall, thin, Japanese version of it with glowing eyes."],
#  ['53',
#   'Normal',
#   'End of evolution',
#   'Belonging to Giovanni, the leader of Team Rocket in the Pokémon anime series, Persian will sneak up behind a foe so silently by retracting its claws. It will then pounce on them and rip them to shreds.'],
#  ['54',
#   'Water',
#   'Golduck (#055)',
#   "When Psyduck's headache gets severe, it unleashes its psychic powers. Psyduck was originally intended to have a currently unnamed middle evolution, but it was scrapped."],
#  ['55',
#   'Water',
#   'End of evolution',
#   'It was almost hunted to extinction by hunters wanting its precious jewel on its forehead.'],
#  ['56',
#   'Fighting',
#   'Primeape (#057)',
#   'Mankey is a Snub-nosed monkey-like Pokémon that specializes in physical fighting and is very aggressive and short-tempered. When angry, Mankey begins shaking and its breathing turns rough. Its rage peaks quickly, preventing its victim from being able to flee.'],
#  ['57',
#   'Fighting',
#   'End of evolution',
#   "Anything can make a Primeape's blood boil. Its not as smart when its really mad, though. However, sometimes it can get so mad, that it can die because it couldn't handle its anger. Primape is based on the Snub-nosed monkey."],
#  ['58',
#   'Fire',
#   'Arcanine (#059)',
#   'A brave and loyal dog Pokémon that will bark and bite to defend its territory from intruders. Growlithe are popular throughout the Pokémon world as both guard dogs and police dogs. They are based on the Ryukyuan Shisa and Japanese Komainu lion-dog statues.'],
#  ['59',
#   'Fire',
#   'End of evolution',
#   'A fan-favorite Pokémon, Arcanine is among the strongest non-legendary Pokémon and has been described as having "the mane of a lion ... the stripes of a tiger [and] the speed of a panther."[18][19][20]'],
#  ['60',
#   'Water',
#   'Poliwhirl (#061)',
#   'Poliwag is the favorite Pokémon of Satoshi Tajiri, creator of the Pokémon franchise.'],
#  ['61',
#   'Water',
#   'Poliwrath (#062)\nPolitoed (#186)',
#   'Poliwhirl is among the most-marketed Pokémon,[21] being used in a line of chewable vitamins as well as a line of toothbrushes.[22][23]'],
#  ['62',
#   'Water',
#   'Fighting',
#   'End of evolution',
#   'Capable of swimming the Pacific Ocean tirelessly.'],
#  ['63',
#   'Psychic',
#   'Kadabra (#064)',
#   'Even when its sleeping, which it does most of its life, it can sense danger. When it is in danger, it will teleport to safety.'],
#  ['64',
#   'Psychic',
#   'Alakazam (#065)',
#   "Kadabra has been the source of various controversies. The symbols on its body have been associated to those used by Nazi Germany's Waffen-SS. Furthermore, in November 2000, Israeli magician Uri Gellar sued Nintendo, claiming Kadabra embodies an unauthorized appropriation of his identity.[24][25][26] However, in 2020, he releases a claim that Nintendo can use Kadabra again."],
#  ['65',
#   'Psychic',
#   'Mega Evolution',
#   'Due to its brain being too heavy in its head, it actually uses its psychic power to hold its head up. Its 5000 IQ makes it a very intelligent Pokémon.'],
#  ['66',
#   'Fighting',
#   'Machoke (#067)',
#   'The best thing about Machop is that its muscles never get sore. It can hurl around 100 adult humans before it gets tired.'],
#  ['67', 'Fighting', 'Machamp (#068)', ''],
#  ['68',
#   'Fighting',
#   'End of evolution',
#   '[Gigantamax] It can throw around 1000 punches in two seconds and move mountains with one arm.'],
#  ['69', 'Grass', 'Poison', 'Weepinbell (#070)', ''],
#  ['70',
#   'Grass',
#   'Poison',
#   'Victreebel (#071)',
#   'It has a hook on its rear end that it hooks on trees with and sleeps. When it wakes up, it might find itself on the ground because of the wind.'],
#  ['71', 'Grass', 'Poison', 'End of evolution', ''],
#  ['72',
#   'Water',
#   'Poison',
#   'Tentacruel (#073)',
#   "If Tentacool isn't in the water, it will shrivel up because it is mostly water."],
#  ['73', 'Water', 'Poison', 'End of evolution', ''],
#  ['74',
#   'Rock',
#   'Ground',
#   'Graveler (#075)',
#   'Sometimes mistaken as ordinary rocks, people mistakenly step on them resulting in them getting hurt.'],
#  ['75', 'Rock', 'Ground', 'Golem (#076)', ''],
#  ['76',
#   'Rock',
#   'Ground',
#   'End of evolution',
#   "Golem is known for rolling down from mountains. To prevent them from rolling into the homes of people downhill, grooves have been dug into the sides of mountains to serve as guideways for diverting this Pokémon's course."],
#  ['77',
#   'Fire',
#   'Rapidash (#078)',
#   'Its Galarian form is a Psychic Type. When born, it cannot stand and runs with its parents to strengthen its legs.'],
#  ['78',
#   'Fire',
#   'End of evolution',
#   'As a popular Pokémon, Rapidash is considered "universally appealing" to fans of cute and cool Pokémon alike.[27][28][29][30]'],
#  ['79',
#   'Water',
#   'Psychic',
#   'Slowbro (#080)\nSlowking (#199)',
#   'Slowpoke eats by dipping its tail in the water. Slowpoke tails are quite a delicacy.'],
#  ['80',
#   'Water',
#   'Psychic',
#   'Mega Evolution',
#   "With Shellder's poison going through its body, it makes it even more spaced out than it already was."],
#  ['81',
#   'Electric',
#   'Steel[nb 3]',
#   'Magneton (#082)',
#   'Was a pure Electric Type in the first games, but had the Steel Type added in Gold and Silver.'],
#  ['82',
#   'Electric',
#   'Steel[nb 3]',
#   'Magnezone (#462)',
#   'Having this Pokemon near mehanical devies is a bad idea. Often times, Cites will warn people to hide their electronics because Magneton produces electromagnetic waves that mostly ruin devices.'],
#  ['83',
#   'Normal',
#   'Flying',
#   'No evolution[nb 4]',
#   "Farfetch'd is a duck-like Pokémon that has a green onion stalk for a weapon. It battles over stalks and eats them at starving times. It will die over its own stalk and battle for the best stalks."],
#  ['84',
#   'Normal',
#   'Flying',
#   'Dodrio (#085)',
#   'A Pokémon with two heads. More skilled at running than flying, it is capable of racing at speeds over 60 mph.'],
#  ['85',
#   'Normal',
#   'Flying',
#   'End of evolution',
#   'The three heads express joy, sorrow and anger as they plan strategy together. When it sleeps, one head remains awake.'],
#  ['86',
#   'Water',
#   'Dewgong (#087)',
#   'When hunting under water, it uses its horn to break a hole out of the ice to breathe.'],
#  ['87',
#   'Water',
#   'Ice',
#   'End of evolution',
#   'Once, a fisherman saw a Dewgong on an iceberg and thought it was a mermaid.'],
#  ['88',
#   'Poison',
#   'Muk (#089)',
#   'It eats sewer waste for food. Its body is very slippery so it can slip through almost any opening.'],
#  ['89',
#   'Poison',
#   'End of evolution',
#   'Muk\'s name comes from the corruption of the word, "muck". A sludge Pokemon that is also be based on Dorotabō, a one-eyed, three-fingered yōkai that rises from the mud of neglected, overgrown rice fields. Its body smells so awful, it can cause fainting. Through degeneration, it lost its sense of smell.'],
#  ['90',
#   'Water',
#   'Cloyster (#091)',
#   'When it sleeps it will still stick its tongue out.'],
#  ['91',
#   'Water',
#   'Ice',
#   'End of evolution',
#   'It swims by push water out though its valves.'],
#  ['92',
#   'Ghost',
#   'Poison',
#   'Haunter (#093)',
#   "A Ghost-type Pokemon based on the will-o'-the-wisp and the yokai, Sōgenbi. It hides under structures to stop the wind from blowing away its gaseous matter."],
#  ['93',
#   'Ghost',
#   'Poison',
#   'Gengar (#094)',
#   "By licking, it saps the victim's life. It causes shaking that won't stop until the victim's demise."],
#  ['94',
#   'Ghost',
#   'Poison',
#   'Mega Evolution',
#   "[Gigantamax] Owing to its simplistic yet appealing design, Gengar is Ken Sugimori's favorite Pokémon as of the release of X and Y.[31]"],
#  ['95',
#   'Rock',
#   'Ground',
#   'Steelix (#208)',
#   'Though its design has been praised, critics deem Onix underpowered compared to other Rock-types of its generation.[1][32][33][34]'],
#  ['96',
#   'Psychic',
#   'Hypno (#097)',
#   'Drowzee is based on the dream-eating tapir, Baku. If your nose is itchy after you awake, a Drowzee has eaten your dreams through your nose.'],
#  ['97',
#   'Psychic',
#   'End of evolution',
#   'Hypno is based on the dream-eating tapir, Baku and a hypnotist. It polishes its pendulum to more effectively put people to sleep. Try not to look at it.'],
#  ['98', 'Water', 'Kingler (#099)', ''],
#  ['99',
#   'Water',
#   'End of evolution',
#   'Can [Gigantamax]. Becauseits pincer is so heavy, it has a hard time fichting. When it does hit, its very powerful.'],
#  ['100',
#   'Electric',
#   'Electrode (#101)',
#   'Voltorb and Electrode are some of the least popular Pokémon because of their Poké Ball-inspired designs. Even the slightest bit of electricity can make an Electrode explode. That\'s why it is nicknamed the "Bomb Ball"'],
#  ['101', 'Electric', 'End of evolution'],
#  ['102',
#   'Grass',
#   'Psychic',
#   'Exeggutor (#103)',
#   "Six of them together form a full-fledged Pokémon. It's often hunted by Crabrawler, but uses psychokinesis to drive it off."],
#  ['103',
#   'Grass',
#   'Psychic',
#   'End of evolution',
#   'A coconut tree-like Pokémon based on the Jinmenju and the favorite Pokémon of Tsunekazu Ishihara, president and CEO of The Pokémon Company, having used it throughout the debugging phase of Pokémon Red and Green. Its 3 heads can think differently, often making it unable to move.'],
#  ['104',
#   'Ground',
#   'Marowak (#105)',
#   'The stains on its skull are caused by the tears it sheds knowing it will never see its mother again.'],
#  ['105',
#   'Ground',
#   'End of evolution',
#   'Marowak has an Alola Form that is a Ghost/Fire type. It was originally intended for Marowak to have a currently unnamed evolution, but it was scrapped.'],
#  ['106',
#   'Fighting',
#   'End of evolution',
#   "Hitmonlee's design is based on Headless men, from Greco-Roman mythology. It may be also be based on Kabandha, a demon from Hindu Mythology. Its name is derived from actor and martial artist Bruce Lee. It will rub its legs down after fighting to overcome fatigue. It also can extend its legs to deliver power kicks."],
#  ['107',
#   'Fighting',
#   'End of evolution',
#   'Its name is derived from actor and martial artist Jackie Chan. It delivers powerful punches in a fight. However, it can only fight for 3 minutes without resting.'],
#  ['108',
#   'Normal',
#   'Lickilicky (#463)',
#   "It can swiftly pick up a small bean with its tongue better than its hands or feet. If it licks you and you don't clean it off, it'll break out into a rash."],
#  ['109',
#   'Poison',
#   'Weezing (#110)',
#   'Koffing is based on air pollution. Sometimes, it can over inflate itself and explode.'],
#  ['110',
#   'Poison',
#   'End of evolution',
#   'A Weezing belonged to James of Team Rocket in the Kanto and Johto series of the Pokémon anime and for a small portion of the Advanced Generation series. It likes to raid trash can for food. To ake its poison more toxic, it pushes its gas through its 2 heads.'],
#  ['111',
#   'Ground',
#   'Rock',
#   'Rhydon (#112)',
#   "Its tackles can demolish skyscrapers but its memory isn't the best. Once it starts going, it sometimes can't remember why it started."],
#  ['112',
#   'Ground',
#   'Rock',
#   'Rhyperior (#464)',
#   'Rhydon was the first Pokémon created by Game Freak.[35] Its hides is very tough.'],
#  ['113',
#   'Normal',
#   'Blissey (#242)',
#   'In generation II, Blissey (#242) was added and in generation IV Happiny (#440) was added. Initially however, Chansey was a stand-alone Pokémon.'],
#  ['114',
#   'Grass',
#   'Tangrowth (#465)',
#   "Blue plant vines cloak the Pokémon's identity in a tangled mass. It entangles anything that gets close. It also resembles the severed head of the gorgon, Medusa."],
#  ['115',
#   'Normal',
#   'Mega Evolution',
#   'In Pokémon Go, Kangaskhan is exclusively found in Australia. It was the second Pokémon created by Game Freak, after Rhydon. It carries a baby Kangaskhan in its pouch until it grows up.'],
#  ['116',
#   'Water',
#   'Seadra (#117)',
#   'Horsea and Seadra are based on seahorses.[36] In the occurrence of a big wave, Horsea will curl its tail around tough coral braches to help it not to be washed away. When going near a Seadra some people forget that it has toxic spikes and often get poised.'],
#  ['117', 'Water', 'Kingdra (#230)'],
#  ['118',
#   'Water',
#   'Seaking (#119)',
#   'Goldeen and Seaking are based on goldfish.[36]'],
#  ['119', 'Water', 'End of evolution'],
#  ['120',
#   'Water',
#   'Starmie (#121)',
#   'Staryu, known as the Star Shape Pokémon, is a basic, Water-type Pokémon which resembles a starfish.'],
#  ['121',
#   'Water',
#   'Psychic',
#   'End of evolution',
#   'Starmie, known as the Mysterious Pokémon, resembles a sea star. Starmie appears to have a second star growing on its back, which is semi-attached, being able to spin 360°. Starmie has a red jewel core, which resembles a cut precious stone and seems to shine with the seven colors of the rainbow when looked at from different angles,[37] but usually shows up red more than any other color. It can also emit electrical waves from the core that are powerful enough to reach the furthest parts of the universe.[38]'],
#  ['122',
#   'Psychic',
#   'Fairy[nb 5]',
#   'End of evolution[nb 6]',
#   'Its pantomiming is the best in the world. If someone interrupts it, it will harshly slap whoever did it with its big, broad hands that can form invisible walls just by vibrating it fingertips.'],
#  ['123',
#   'Bug',
#   'Flying',
#   'Scizor (#212)',
#   'IGN and GamesRadar have praised Scyther\'s "cool" design.[39][40][41]'],
#  ['124',
#   'Ice',
#   'Psychic',
#   'End of evolution',
#   'Jynx has spawned controversy due to aspects of its design being similar to blackface, leading Game Freak to change the color of its skin from black to purple.[42][43][44][45][46] When Pokémon Yellow was re-released on the Nintendo 3DS Virtual Console, the in-game sprite of Jynx was edited to reflect this change.[46]'],
#  ['125',
#   'Electric',
#   'Electivire (#466)',
#   'It gathers near power plants to feast on electricity. In the dark, it glows a whitish blue color.'],
#  ['126',
#   'Fire',
#   'Magmortar (#467)',
#   'While Magmar was voted the eighth best fire-type Pokémon by the Official Nintendo Magazine readers,[47] GamesRadar has criticized its design multiple times, noting that its forehead resembles a butt.[48][49]'],
#  ['127',
#   'Bug',
#   'Mega Evolution',
#   'It likes to throw things with its massive horns. It can throw things 2x its weight.'],
#  ['128',
#   'Normal',
#   'No evolution',
#   'It is voiced by Toshiyuki Morikawa in Pokémon X and Y - present.'],
#  ['129',
#   'Water',
#   'Gyarados (#130)',
#   'Magikarp holds the distinction of being mostly useless in the games, until it evolves into the superior Gyarados. Magikarp is based on the common carp.[36]'],
#  ['130',
#   'Water',
#   'Flying',
#   'Mega Evolution',
#   'In the beta versions for Pokémon Red and Blue, Gyarados was originally named "Skullkraken". Gyarados is inspired by the myth of a carp jumping over the Dragon Gate. Its vicious and raging attitude can decimate cities.'],
#  ['131',
#   'Water',
#   'Ice',
#   'No evolution',
#   '[Gigantamax] Has a very gentle nature. Was hunted before it became illegal. Gigantamax Lapras is exclusive to Shield.'],
#  ['132',
#   'Normal',
#   'No evolution',
#   'The favorite Pokémon of Hideo Kojima,[50] Ditto is capable of transforming into any Pokémon it comes across.'],
#  ['133',
#   'Normal',
#   'Multiple[nb 7]',
#   '[Gigantamax] Eevee is often considered among the "cutest" Pokémon in the franchise.[51][52][53][54] Because of this, Eevee is featured on various Pokémon-related merchandise.[55][56][57] Mascot of Pokémon: Let\'s Go, Eevee!'],
#  ['134',
#   'Water',
#   'End of Evolution',
#   'When its in water, because its molecules are very similar to water, it will seem to invisibly melt in water.'],
#  ['135',
#   'Electric',
#   'End of evolution',
#   "Jolteon and Zapdos's romanized Japanese names are almost exactly the same as each other's, with a final's being the only difference."],
#  ['136',
#   'Fire',
#   'End of evolution',
#   'Flareon shares its category name with Charmeleon, Charizard, Moltres, and Infernape. They are all known as the Flame Pokémon.'],
#  ['137',
#   'Normal',
#   'Porygon2 (#233)',
#   'Porygon has become notorious for being featured in an episode of the anime that caused widespread epileptic seizures in Japanese viewers.[58] It can be really helpful with scientists because since it can go in to cyberspace at will, it looks for malicious malware in computers.'],
#  ['138',
#   'Rock',
#   'Water',
#   'Omastar (#139)',
#   'A fossil Pokémon that must be revived from the helix fossil.'],
#  ['139',
#   'Rock',
#   'Water',
#   'End of evolution',
#   'Omastar is very popular in the community and commonly referred to as "Lord Helix". This is a reference to Twitch Plays Pokémon, where the Pokémon was seen as a good luck charm.'],
#  ['140',
#   'Rock',
#   'Water',
#   'Kabutops (#141)',
#   'A fossil Pokémon that must be revived from the dome fossil.'],
#  ['141',
#   'Rock',
#   'Water',
#   'End of evolution',
#   'Its slender body makes it a very fast swimmer.'],
#  ['142',
#   'Rock',
#   'Flying',
#   'Mega Evolution',
#   "A fossil Pokémon that must be revived from the old amber. It used to rule the skies back when it was alive. Now not even computers can't even revive it to make it what it used to look like."],
#  ['143',
#   'Normal',
#   'End of evolution',
#   '[Gigantamax] It is carefree about everything and it will allow children to play on its vast belly while it sleeps all day. After eating around 500 pounds of food, it goes flat to sleep for a while.'],
#  ['144',
#   'Ice',
#   'Flying',
#   'No evolution',
#   'Part of the Legendary Birds. The naming conventions for this trio are based on their type - Artic, Zap and Molt - along with a 1, 2, 3 in Spanish - uno, dos, tres. As it flies, snow drifts from its wings.'],
#  ['145',
#   'Electric',
#   'Flying',
#   'No evolution',
#   'Part of the Legendary Birds. Design inspired by the Indigenous North American myth of the thunderbird.[17]'],
#  ['146',
#   'Fire',
#   'Flying',
#   'No evolution',
#   'Part of the Legendary Birds. Design inspired by the firebird of Slavic folklore.[17]'],
#  ['147',
#   'Dragon',
#   'Dragonair (#148)',
#   'Its existence was unknown until a fisherman pulled it up after fishing for 10 hours straight.'],
#  ['148', 'Dragon', 'Dragonite (#149)', ''],
#  ['149',
#   'Dragon',
#   'Flying',
#   'End of evolution',
#   'Pseudo-Legendary. It zooms off over seas to challenge other Pokémon.'],
#  ['150',
#   'Psychic',
#   'Two Mega Evolutions',
#   "Legendary. One of the playable characters in Super Smash Bros. Melee, Super Smash Bros. for Nintendo 3DS / Wii U and Super Smash Bros. Ultimate. Its genes were spliced and restructured from Mew's. However, its attutude is far more vile that it. Plus some say its the strongest Pokémon out there, but no one can say for sure."],
#  ['151',
#   'Psychic',
#   'No evolution',
#   'Only available through Nintendo events. It can turn invisible at will and it can turn into anything at will.'],
#  ['None[nb 8]',
#   'Bird[nb 9]',
#   'Normal',
#   'No evolution',
#   'An error handler species, "Missing Number" was created to handle attempts at accessing nonexistent Pokémon species.[59][60] It is regarded as one of the most famous and popular glitches in video game history.[61]']]

# %%
elements[5][4]
# Out:
# '[Gigantamax] Playable character as a part of the "Pokémon Trainer" fighter in Super Smash Bros. Brawl and Super Smash Bros. Ultimate, as well as a standalone fighter in Super Smash Bros. for Nintendo 3DS and Wii U. Its English name is a portmanteau of "char" and "lizard".[10] Its Gigantamax Form has literal fire for wings and has fire coming out of its body. Mascot of Pokémon Red and FireRed.'

# %% [markdown]
# We need to make a workaround to collect the notes information column. It happens that our table has some merged cells either on the Type(s) heads or two different Pokémon share the same note. Therefore, the lenght of our elements list above can either be:
#
#    + 5: in that case, we should collect the information within elements [i][4]
#    + 4: in that case, we should collect the information within elements [i][3]
#    + 3: in that case, we should collect the information within elements [i][2]
#
# Note that the same information applies for any other information we might want to collect from the dataset. This is just a particular case. In general case would be:
#
#    + 5: in that case, we should collect the information within elements [i][n]
#    + 4: in that case, we should collect the information within elements [i][n-1]
#    + 3: in that case, we should collect the information within elements [i][n-2]
#
# Being n the index for a given position vector within the maximum indexes of the matrix elements

# %%
lenght=[]
for e in elements:
    lenght.append(len(e))
    
set(lenght)
# Out:
# {3, 4, 5}

# %%
count=0
for e, l in enumerate(lenght):
    if l == 3:
        count += 1
        print(e)
count
# Out:
# 100
# 116
# 118
# 3

# %% [markdown]
# There are 3 vectors/ 4 Pokémon that are missing this note information they are (print(e) allows us to identify them):
#
#    + #100 Voltorb
#    + #101 Electrode
#    + #116 Horsea
#    + #117 Seadra
#
# Let's collect the notes, taken into account that the information within the mentioned column either doesn't exist at all or exists in one time in only the above mentioned

# %%
notes = []
evolutions = []

for i, e in enumerate(elements):
    if len(e) == 5:
        notes.append(elements[i][4])
        evolutions.append(elements[i][3])
    elif len(e) == 4:
        notes.append(elements[i][3])
        evolutions.append(elements[i][2])
    else:
        notes.append(elements[i][2])
        evolutions.append(elements[i][1])
        
len(notes) == len(evolutions)
# Out:
# True

# %%
notes
# Out:
# ['Reception to Bulbasaur has been largely positive and it often appears in "top Pokémon lists".[3][4] Its English name is a portmanteau of "bulb" and "dinosaur".[5] It shares its category with Ivysaur, Venusaur and Sunkern. They are all known as the Seed Pokémon.',
#  'Playable character in Super Smash Bros. Brawl and Super Smash Bros. Ultimate as a part of the "Pokémon Trainer" fighter. Its English name is a portmanteau of "ivy" and "dinosaur".[6]',
#  '[Gigantamax] Its English name is a portmanteau of "Venus" (relating to the Venus flytrap) and "dinosaur". It is the mascot of Pokémon Green and LeafGreen.[7] It is based on the Pareiasaur.',
#  'Charmander is a bipedal, salamander-like creature with a flame at the tip of its tail. Its English name is a portmanteau of "char" and "salamander".[8]',
#  'Charmeleon shares a nearly identical design to Charmander, though is larger in stature. Its English name is a portmanteau of "char" and "chameleon".[9]',
#  '[Gigantamax] Playable character as a part of the "Pokémon Trainer" fighter in Super Smash Bros. Brawl and Super Smash Bros. Ultimate, as well as a standalone fighter in Super Smash Bros. for Nintendo 3DS and Wii U. Its English name is a portmanteau of "char" and "lizard".[10] Its Gigantamax Form has literal fire for wings and has fire coming out of its body. Mascot of Pokémon Red and FireRed.',
#  'Playable character in Super Smash Bros. Brawl and Super Smash Bros. Ultimate as a part of the "Pokémon Trainer" fighter. Its English name is a portmanteau of "squirt" and "turtle".[11]',
#  'Its English name is a portmanteau of "war", "tortoise" and "turtle".[12]',
#  '[Gigantamax] Its English name is a portmanteau of "blast" and "tortoise". Mascot of Pokémon Blue.[13]In early stages of Red and Green\'s development, Blastoise was originally called "Caravaggio", which is believed to be a reference to the Teenage Mutant Ninja Turtles franchise.',
#  'To avoid predators, it releases an odor that makes bird Pokémon think twice about going after it.',
#  'It tries to move as little as possible because if its fragile body broke, its liquid guts would spill out, killing it.',
#  '[Gigantamax] If you put pollen out of your window, a Butterfree will come to you. A Gigantamaxed Butterfree can grow a tremendous size with huge light blue wings.',
#  'Its stinger is poisonous so if it finds itself against a foe, it can protect itself for a while.',
#  "Similar to Metapod, it can't really move because it is melting its own body to evolve.",
#  'Never go near a Beedrill nest because every Beedrill in the nest will angrily swarm you and sting you repeatedly, which is poisonous as well.',
#  'The common bird of Kanto, Pidgey is a bird that will go after bug Pokémon until it scurries away.',
#  'Pidgeotto was the second Pokémon that Ash Ketchum caught on his journey in the anime.',
#  'A lot of Trainers choose Pidgeot as their Pokémon because of the striking beautiful feathers it has.',
#  'Criticized as a "filthy rodent" by GamesRadar and "rubbish" by the Official Nintendo Magazine.[14][15] Its teeth grow very long over time, so it has to gnaw on logs, houses, telephone poles and more so it can be quite a pest at times.',
#  'Raticate is a rodent that commands the groups of Rattatas to get it food. Like Rattata, it too needs to whittle its teeth down but it does so on harder objects like steel, wood, rocks, fruit, and more.',
#  'Eats bugs in grassy areas. It has to flap its short wings at high speed to stay airborne.',
#  'Its English name is a portmanteau of "fear" and "sparrow".',
#  "Its English name is “snake” spelled backwards. Ekans likes to coil itself because if it gets attacked while sleeping, it's all ready to strike at them.",
#  'Belonged to Jessie, a member of Team Rocket, for the Kanto, Johto, and a small portion of the Advanced Generation series of the Pokémon anime. The pattern on its chest is different everywhere. It is hard to escape from its coil because its muscles are so strong. Even though its name is Arbok, what it pronounces is "Char-bok". Its name backwards is kobra, which is pronounced the same as cobra',
#  "[Gigantamax] Mascot of the Pokémon franchise, as well as Pokémon Yellow and Let's Go, Pikachu! Also playable in every Super Smash Bros. game to date. Gigantamax Pikachu looks like its old sprite from Red and Blue with a glowing whitish tail. It raises its tail to check its surroundings and it sometimes gets struck by lightning in that pose. If Pikachu sees something new, it'll shock it with electricity. When you see blackened marks on the ground, Pikachu mistook its electrical power.",
#  'Raichu has an Alola Form that is an Electric/Psychic Type. It was originally intended for Raichu to have an evolution named Gorochu, but it was scrapped due to balance issues.',
#  'Sandshrew has an Alola Form that is a Steel/Ice Type. Based on the Chinese pangolin, Sandshrew is known to curl into a ball to defend itself similar to volvation seen in animals.',
#  'Sandslash is a pangolin-like Pokémon Curls up into a spiny ball when threatened. It can roll while curled up to attack or escape. Sandslash has an Alola Form that is a Steel/Ice Type.',
#  "It is related to the Nidoran♂ line, and can produce Eggs that contain either Nidoran♀ or Nidoran♂. However, it is the only one of its line that can breed, as Nidorina and Nidoqueen are part of the Undiscovered Egg Group. Both Nidoran's, Nidorina, Nidorino, Poipole, and Naganadel are known as the Poison Pin Pokémon.",
#  "When it's with its friends and family, it doesn't have its toxic horn out. As soon as danger appears, it is ready to fight.",
#  'When protecting its young, it gains more strength than normal. Its hide is so strong, not much can hurt it.',
#  '',
#  '',
#  'Based on Baragon from the Godzilla franchise, It usually fights for the family if its offspring are in trouble.',
#  "Originally proposed to be joint mascot of the Pokémon franchise alongside Pikachu, but was quickly overshadowed by the latter's popularity[16]",
#  'Clefairy evolves into Clefable when coming contact with a moon stone',
#  'When a Vulpix is born, it only has one white tail that splits into 6 if it gets plenty of love from its Trainer or mother.',
#  'Designs inspired by the nine-tailed fox of East Asian myth.[17]',
#  'Playable in every Super Smash Bros. game to date.',
#  "It doesn't care if its large eyes gets dust or dirt in them because its eyes are covered in a thin layer of fluid.",
#  'It uses echolocation because it has no eyes.',
#  "Golbat loves to drink blood, however it sometimes drinks so much that it can't fly.",
#  'It buries itself in the soil to absorb the nutrients. the more water it drinks, the glossier it becomes.',
#  "If it senses danger around it, it produces a horrific stench from the leaves on its head. If there isn't, it's fine and the stench goes away.",
#  "Tour guides always say not to go up to any flower in the jungle, no matter how beautiful is because of this reason: it might just be a Vileplume which can spread toxic spores that will leave you sick for days. Vileplume is based on the Rafflesia, the world's smelliest flower.",
#  "When a Paras eats, its body isn't getting most of the nutrients, the mushrooms on its back are. Those mushrooms can also be used for medicinal purposes.",
#  'It hollows out trees to absorb its energy. When the tree dies, it will move on to the next. The mushroom has essentially killed it leaving its host to forage for it.',
#  '',
#  '',
#  'Farmers like to use Digletts to plow the soil for crops to grow plentifully.',
#  '',
#  "[Gigantamax] Reoccurring member of Team Rocket in the Pokémon anime series, Meowth loves anything shiny and will steal it if it can. Murkrow and Meowth will loot each other's stash all the time. Gigantamax Meowth is a tall, thin, Japanese version of it with glowing eyes.",
#  'Belonging to Giovanni, the leader of Team Rocket in the Pokémon anime series, Persian will sneak up behind a foe so silently by retracting its claws. It will then pounce on them and rip them to shreds.',
#  "When Psyduck's headache gets severe, it unleashes its psychic powers. Psyduck was originally intended to have a currently unnamed middle evolution, but it was scrapped.",
#  'It was almost hunted to extinction by hunters wanting its precious jewel on its forehead.',
#  'Mankey is a Snub-nosed monkey-like Pokémon that specializes in physical fighting and is very aggressive and short-tempered. When angry, Mankey begins shaking and its breathing turns rough. Its rage peaks quickly, preventing its victim from being able to flee.',
#  "Anything can make a Primeape's blood boil. Its not as smart when its really mad, though. However, sometimes it can get so mad, that it can die because it couldn't handle its anger. Primape is based on the Snub-nosed monkey.",
#  'A brave and loyal dog Pokémon that will bark and bite to defend its territory from intruders. Growlithe are popular throughout the Pokémon world as both guard dogs and police dogs. They are based on the Ryukyuan Shisa and Japanese Komainu lion-dog statues.',
#  'A fan-favorite Pokémon, Arcanine is among the strongest non-legendary Pokémon and has been described as having "the mane of a lion ... the stripes of a tiger [and] the speed of a panther."[18][19][20]',
#  'Poliwag is the favorite Pokémon of Satoshi Tajiri, creator of the Pokémon franchise.',
#  'Poliwhirl is among the most-marketed Pokémon,[21] being used in a line of chewable vitamins as well as a line of toothbrushes.[22][23]',
#  'Capable of swimming the Pacific Ocean tirelessly.',
#  'Even when its sleeping, which it does most of its life, it can sense danger. When it is in danger, it will teleport to safety.',
#  "Kadabra has been the source of various controversies. The symbols on its body have been associated to those used by Nazi Germany's Waffen-SS. Furthermore, in November 2000, Israeli magician Uri Gellar sued Nintendo, claiming Kadabra embodies an unauthorized appropriation of his identity.[24][25][26] However, in 2020, he releases a claim that Nintendo can use Kadabra again.",
#  'Due to its brain being too heavy in its head, it actually uses its psychic power to hold its head up. Its 5000 IQ makes it a very intelligent Pokémon.',
#  'The best thing about Machop is that its muscles never get sore. It can hurl around 100 adult humans before it gets tired.',
#  '',
#  '[Gigantamax] It can throw around 1000 punches in two seconds and move mountains with one arm.',
#  '',
#  'It has a hook on its rear end that it hooks on trees with and sleeps. When it wakes up, it might find itself on the ground because of the wind.',
#  '',
#  "If Tentacool isn't in the water, it will shrivel up because it is mostly water.",
#  '',
#  'Sometimes mistaken as ordinary rocks, people mistakenly step on them resulting in them getting hurt.',
#  '',
#  "Golem is known for rolling down from mountains. To prevent them from rolling into the homes of people downhill, grooves have been dug into the sides of mountains to serve as guideways for diverting this Pokémon's course.",
#  'Its Galarian form is a Psychic Type. When born, it cannot stand and runs with its parents to strengthen its legs.',
#  'As a popular Pokémon, Rapidash is considered "universally appealing" to fans of cute and cool Pokémon alike.[27][28][29][30]',
#  'Slowpoke eats by dipping its tail in the water. Slowpoke tails are quite a delicacy.',
#  "With Shellder's poison going through its body, it makes it even more spaced out than it already was.",
#  'Was a pure Electric Type in the first games, but had the Steel Type added in Gold and Silver.',
#  'Having this Pokemon near mehanical devies is a bad idea. Often times, Cites will warn people to hide their electronics because Magneton produces electromagnetic waves that mostly ruin devices.',
#  "Farfetch'd is a duck-like Pokémon that has a green onion stalk for a weapon. It battles over stalks and eats them at starving times. It will die over its own stalk and battle for the best stalks.",
#  'A Pokémon with two heads. More skilled at running than flying, it is capable of racing at speeds over 60 mph.',
#  'The three heads express joy, sorrow and anger as they plan strategy together. When it sleeps, one head remains awake.',
#  'When hunting under water, it uses its horn to break a hole out of the ice to breathe.',
#  'Once, a fisherman saw a Dewgong on an iceberg and thought it was a mermaid.',
#  'It eats sewer waste for food. Its body is very slippery so it can slip through almost any opening.',
#  'Muk\'s name comes from the corruption of the word, "muck". A sludge Pokemon that is also be based on Dorotabō, a one-eyed, three-fingered yōkai that rises from the mud of neglected, overgrown rice fields. Its body smells so awful, it can cause fainting. Through degeneration, it lost its sense of smell.',
#  'When it sleeps it will still stick its tongue out.',
#  'It swims by push water out though its valves.',
#  "A Ghost-type Pokemon based on the will-o'-the-wisp and the yokai, Sōgenbi. It hides under structures to stop the wind from blowing away its gaseous matter.",
#  "By licking, it saps the victim's life. It causes shaking that won't stop until the victim's demise.",
#  "[Gigantamax] Owing to its simplistic yet appealing design, Gengar is Ken Sugimori's favorite Pokémon as of the release of X and Y.[31]",
#  'Though its design has been praised, critics deem Onix underpowered compared to other Rock-types of its generation.[1][32][33][34]',
#  'Drowzee is based on the dream-eating tapir, Baku. If your nose is itchy after you awake, a Drowzee has eaten your dreams through your nose.',
#  'Hypno is based on the dream-eating tapir, Baku and a hypnotist. It polishes its pendulum to more effectively put people to sleep. Try not to look at it.',
#  '',
#  'Can [Gigantamax]. Becauseits pincer is so heavy, it has a hard time fichting. When it does hit, its very powerful.',
#  'Voltorb and Electrode are some of the least popular Pokémon because of their Poké Ball-inspired designs. Even the slightest bit of electricity can make an Electrode explode. That\'s why it is nicknamed the "Bomb Ball"',
#  'End of evolution',
#  "Six of them together form a full-fledged Pokémon. It's often hunted by Crabrawler, but uses psychokinesis to drive it off.",
#  'A coconut tree-like Pokémon based on the Jinmenju and the favorite Pokémon of Tsunekazu Ishihara, president and CEO of The Pokémon Company, having used it throughout the debugging phase of Pokémon Red and Green. Its 3 heads can think differently, often making it unable to move.',
#  'The stains on its skull are caused by the tears it sheds knowing it will never see its mother again.',
#  'Marowak has an Alola Form that is a Ghost/Fire type. It was originally intended for Marowak to have a currently unnamed evolution, but it was scrapped.',
#  "Hitmonlee's design is based on Headless men, from Greco-Roman mythology. It may be also be based on Kabandha, a demon from Hindu Mythology. Its name is derived from actor and martial artist Bruce Lee. It will rub its legs down after fighting to overcome fatigue. It also can extend its legs to deliver power kicks.",
#  'Its name is derived from actor and martial artist Jackie Chan. It delivers powerful punches in a fight. However, it can only fight for 3 minutes without resting.',
#  "It can swiftly pick up a small bean with its tongue better than its hands or feet. If it licks you and you don't clean it off, it'll break out into a rash.",
#  'Koffing is based on air pollution. Sometimes, it can over inflate itself and explode.',
#  'A Weezing belonged to James of Team Rocket in the Kanto and Johto series of the Pokémon anime and for a small portion of the Advanced Generation series. It likes to raid trash can for food. To ake its poison more toxic, it pushes its gas through its 2 heads.',
#  "Its tackles can demolish skyscrapers but its memory isn't the best. Once it starts going, it sometimes can't remember why it started.",
#  'Rhydon was the first Pokémon created by Game Freak.[35] Its hides is very tough.',
#  'In generation II, Blissey (#242) was added and in generation IV Happiny (#440) was added. Initially however, Chansey was a stand-alone Pokémon.',
#  "Blue plant vines cloak the Pokémon's identity in a tangled mass. It entangles anything that gets close. It also resembles the severed head of the gorgon, Medusa.",
#  'In Pokémon Go, Kangaskhan is exclusively found in Australia. It was the second Pokémon created by Game Freak, after Rhydon. It carries a baby Kangaskhan in its pouch until it grows up.',
#  'Horsea and Seadra are based on seahorses.[36] In the occurrence of a big wave, Horsea will curl its tail around tough coral braches to help it not to be washed away. When going near a Seadra some people forget that it has toxic spikes and often get poised.',
#  'Kingdra (#230)',
#  'Goldeen and Seaking are based on goldfish.[36]',
#  'End of evolution',
#  'Staryu, known as the Star Shape Pokémon, is a basic, Water-type Pokémon which resembles a starfish.',
#  'Starmie, known as the Mysterious Pokémon, resembles a sea star. Starmie appears to have a second star growing on its back, which is semi-attached, being able to spin 360°. Starmie has a red jewel core, which resembles a cut precious stone and seems to shine with the seven colors of the rainbow when looked at from different angles,[37] but usually shows up red more than any other color. It can also emit electrical waves from the core that are powerful enough to reach the furthest parts of the universe.[38]',
#  'Its pantomiming is the best in the world. If someone interrupts it, it will harshly slap whoever did it with its big, broad hands that can form invisible walls just by vibrating it fingertips.',
#  'IGN and GamesRadar have praised Scyther\'s "cool" design.[39][40][41]',
#  'Jynx has spawned controversy due to aspects of its design being similar to blackface, leading Game Freak to change the color of its skin from black to purple.[42][43][44][45][46] When Pokémon Yellow was re-released on the Nintendo 3DS Virtual Console, the in-game sprite of Jynx was edited to reflect this change.[46]',
#  'It gathers near power plants to feast on electricity. In the dark, it glows a whitish blue color.',
#  'While Magmar was voted the eighth best fire-type Pokémon by the Official Nintendo Magazine readers,[47] GamesRadar has criticized its design multiple times, noting that its forehead resembles a butt.[48][49]',
#  'It likes to throw things with its massive horns. It can throw things 2x its weight.',
#  'It is voiced by Toshiyuki Morikawa in Pokémon X and Y - present.',
#  'Magikarp holds the distinction of being mostly useless in the games, until it evolves into the superior Gyarados. Magikarp is based on the common carp.[36]',
#  'In the beta versions for Pokémon Red and Blue, Gyarados was originally named "Skullkraken". Gyarados is inspired by the myth of a carp jumping over the Dragon Gate. Its vicious and raging attitude can decimate cities.',
#  '[Gigantamax] Has a very gentle nature. Was hunted before it became illegal. Gigantamax Lapras is exclusive to Shield.',
#  'The favorite Pokémon of Hideo Kojima,[50] Ditto is capable of transforming into any Pokémon it comes across.',
#  '[Gigantamax] Eevee is often considered among the "cutest" Pokémon in the franchise.[51][52][53][54] Because of this, Eevee is featured on various Pokémon-related merchandise.[55][56][57] Mascot of Pokémon: Let\'s Go, Eevee!',
#  'When its in water, because its molecules are very similar to water, it will seem to invisibly melt in water.',
#  "Jolteon and Zapdos's romanized Japanese names are almost exactly the same as each other's, with a final's being the only difference.",
#  'Flareon shares its category name with Charmeleon, Charizard, Moltres, and Infernape. They are all known as the Flame Pokémon.',
#  'Porygon has become notorious for being featured in an episode of the anime that caused widespread epileptic seizures in Japanese viewers.[58] It can be really helpful with scientists because since it can go in to cyberspace at will, it looks for malicious malware in computers.',
#  'A fossil Pokémon that must be revived from the helix fossil.',
#  'Omastar is very popular in the community and commonly referred to as "Lord Helix". This is a reference to Twitch Plays Pokémon, where the Pokémon was seen as a good luck charm.',
#  'A fossil Pokémon that must be revived from the dome fossil.',
#  'Its slender body makes it a very fast swimmer.',
#  "A fossil Pokémon that must be revived from the old amber. It used to rule the skies back when it was alive. Now not even computers can't even revive it to make it what it used to look like.",
#  '[Gigantamax] It is carefree about everything and it will allow children to play on its vast belly while it sleeps all day. After eating around 500 pounds of food, it goes flat to sleep for a while.',
#  'Part of the Legendary Birds. The naming conventions for this trio are based on their type - Artic, Zap and Molt - along with a 1, 2, 3 in Spanish - uno, dos, tres. As it flies, snow drifts from its wings.',
#  'Part of the Legendary Birds. Design inspired by the Indigenous North American myth of the thunderbird.[17]',
#  'Part of the Legendary Birds. Design inspired by the firebird of Slavic folklore.[17]',
#  'Its existence was unknown until a fisherman pulled it up after fishing for 10 hours straight.',
#  '',
#  'Pseudo-Legendary. It zooms off over seas to challenge other Pokémon.',
#  "Legendary. One of the playable characters in Super Smash Bros. Melee, Super Smash Bros. for Nintendo 3DS / Wii U and Super Smash Bros. Ultimate. Its genes were spliced and restructured from Mew's. However, its attutude is far more vile that it. Plus some say its the strongest Pokémon out there, but no one can say for sure.",
#  'Only available through Nintendo events. It can turn invisible at will and it can turn into anything at will.',
#  'An error handler species, "Missing Number" was created to handle attempts at accessing nonexistent Pokémon species.[59][60] It is regarded as one of the most famous and popular glitches in video game history.[61]']

# %% [markdown]
# The column contains Missing no which an error and a wholer other topic. Let's remove it for now!

# %%
note = notes[:151]
evol =  evolutions[:151]
evol
# Out:
# ['Ivysaur (#002)',
#  'Venusaur (#003)',
#  'Mega Evolution',
#  'Charmeleon (#005)',
#  'Charizard (#006)',
#  'Two Mega Evolutions',
#  'Wartortle (#008)',
#  'Blastoise (#009)',
#  'Mega Evolution',
#  'Metapod (#011)',
#  'Butterfree (#012)',
#  'End of evolution',
#  'Kakuna (#014)',
#  'Beedrill (#015)',
#  'Mega Evolution',
#  'Pidgeotto (#017)',
#  'Pidgeot (#018)',
#  'Mega Evolution',
#  'Raticate (#020)',
#  'End of evolution',
#  'Fearow (#022)',
#  'End of evolution',
#  'Arbok (#024)',
#  'End of evolution',
#  'Raichu (#026)',
#  'End of evolution',
#  'Sandslash (#028)',
#  'End of evolution',
#  'Nidorina (#030)',
#  'Nidoqueen (#031)',
#  'End of evolution',
#  'Nidorino (#033)',
#  'Nidoking (#034)',
#  'End of evolution',
#  'Clefable (#036)',
#  'End of evolution',
#  'Ninetales (#038)',
#  'End of evolution',
#  'Wigglytuff (#040)',
#  'End of evolution',
#  'Golbat (#042)',
#  'Crobat (#169)',
#  'Gloom (#044)',
#  'Vileplume (#045)\nBellossom (#182)',
#  'End of evolution',
#  'Parasect (#047)',
#  'End of evolution',
#  'Venomoth (#049)',
#  'End of evolution',
#  'Dugtrio (#051)',
#  'End of evolution',
#  'Persian (#053)',
#  'End of evolution',
#  'Golduck (#055)',
#  'End of evolution',
#  'Primeape (#057)',
#  'End of evolution',
#  'Arcanine (#059)',
#  'End of evolution',
#  'Poliwhirl (#061)',
#  'Poliwrath (#062)\nPolitoed (#186)',
#  'End of evolution',
#  'Kadabra (#064)',
#  'Alakazam (#065)',
#  'Mega Evolution',
#  'Machoke (#067)',
#  'Machamp (#068)',
#  'End of evolution',
#  'Weepinbell (#070)',
#  'Victreebel (#071)',
#  'End of evolution',
#  'Tentacruel (#073)',
#  'End of evolution',
#  'Graveler (#075)',
#  'Golem (#076)',
#  'End of evolution',
#  'Rapidash (#078)',
#  'End of evolution',
#  'Slowbro (#080)\nSlowking (#199)',
#  'Mega Evolution',
#  'Magneton (#082)',
#  'Magnezone (#462)',
#  'No evolution[nb 4]',
#  'Dodrio (#085)',
#  'End of evolution',
#  'Dewgong (#087)',
#  'End of evolution',
#  'Muk (#089)',
#  'End of evolution',
#  'Cloyster (#091)',
#  'End of evolution',
#  'Haunter (#093)',
#  'Gengar (#094)',
#  'Mega Evolution',
#  'Steelix (#208)',
#  'Hypno (#097)',
#  'End of evolution',
#  'Kingler (#099)',
#  'End of evolution',
#  'Electrode (#101)',
#  'Electric',
#  'Exeggutor (#103)',
#  'End of evolution',
#  'Marowak (#105)',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'Lickilicky (#463)',
#  'Weezing (#110)',
#  'End of evolution',
#  'Rhydon (#112)',
#  'Rhyperior (#464)',
#  'Blissey (#242)',
#  'Tangrowth (#465)',
#  'Mega Evolution',
#  'Seadra (#117)',
#  'Water',
#  'Seaking (#119)',
#  'Water',
#  'Starmie (#121)',
#  'End of evolution',
#  'End of evolution[nb 6]',
#  'Scizor (#212)',
#  'End of evolution',
#  'Electivire (#466)',
#  'Magmortar (#467)',
#  'Mega Evolution',
#  'No evolution',
#  'Gyarados (#130)',
#  'Mega Evolution',
#  'No evolution',
#  'No evolution',
#  'Multiple[nb 7]',
#  'End of Evolution',
#  'End of evolution',
#  'End of evolution',
#  'Porygon2 (#233)',
#  'Omastar (#139)',
#  'End of evolution',
#  'Kabutops (#141)',
#  'End of evolution',
#  'Mega Evolution',
#  'End of evolution',
#  'No evolution',
#  'No evolution',
#  'No evolution',
#  'Dragonair (#148)',
#  'Dragonite (#149)',
#  'End of evolution',
#  'Two Mega Evolutions',
#  'No evolution']

# %%
evolution = [ev.replace('[nb 7]', '',)\
             .replace('\nSlowking (#199)','')\
             .replace('\nPolitoed (#186)','')\
             .replace('\nBellossom (#182)','')\
             .replace('Crobat (#169)','End of evolution')\
             .replace('Mega Evolution','End of evolution')\
             .replace('Rhyperior (#464)','End of evolution')\
             .replace('Blissey (#242)','End of evolution')\
             .replace('Two End of evolutions','End of evolution')
             .replace('Magmortar (#467)','End of evolution')
             .replace('Electivire (#466)','End of evolution')
             .replace('Scizor (#212)','End of evolution')
             .replace('[nb 6]','End of evolution')
             .replace('Water','End of evolution')
             .replace('Tangrowth (#465)','End of evolution')
             for ev in evol]

# %%
evolution
# Out:
# ['Ivysaur (#002)',
#  'Venusaur (#003)',
#  'End of evolution',
#  'Charmeleon (#005)',
#  'Charizard (#006)',
#  'End of evolution',
#  'Wartortle (#008)',
#  'Blastoise (#009)',
#  'End of evolution',
#  'Metapod (#011)',
#  'Butterfree (#012)',
#  'End of evolution',
#  'Kakuna (#014)',
#  'Beedrill (#015)',
#  'End of evolution',
#  'Pidgeotto (#017)',
#  'Pidgeot (#018)',
#  'End of evolution',
#  'Raticate (#020)',
#  'End of evolution',
#  'Fearow (#022)',
#  'End of evolution',
#  'Arbok (#024)',
#  'End of evolution',
#  'Raichu (#026)',
#  'End of evolution',
#  'Sandslash (#028)',
#  'End of evolution',
#  'Nidorina (#030)',
#  'Nidoqueen (#031)',
#  'End of evolution',
#  'Nidorino (#033)',
#  'Nidoking (#034)',
#  'End of evolution',
#  'Clefable (#036)',
#  'End of evolution',
#  'Ninetales (#038)',
#  'End of evolution',
#  'Wigglytuff (#040)',
#  'End of evolution',
#  'Golbat (#042)',
#  'End of evolution',
#  'Gloom (#044)',
#  'Vileplume (#045)',
#  'End of evolution',
#  'Parasect (#047)',
#  'End of evolution',
#  'Venomoth (#049)',
#  'End of evolution',
#  'Dugtrio (#051)',
#  'End of evolution',
#  'Persian (#053)',
#  'End of evolution',
#  'Golduck (#055)',
#  'End of evolution',
#  'Primeape (#057)',
#  'End of evolution',
#  'Arcanine (#059)',
#  'End of evolution',
#  'Poliwhirl (#061)',
#  'Poliwrath (#062)',
#  'End of evolution',
#  'Kadabra (#064)',
#  'Alakazam (#065)',
#  'End of evolution',
#  'Machoke (#067)',
#  'Machamp (#068)',
#  'End of evolution',
#  'Weepinbell (#070)',
#  'Victreebel (#071)',
#  'End of evolution',
#  'Tentacruel (#073)',
#  'End of evolution',
#  'Graveler (#075)',
#  'Golem (#076)',
#  'End of evolution',
#  'Rapidash (#078)',
#  'End of evolution',
#  'Slowbro (#080)',
#  'End of evolution',
#  'Magneton (#082)',
#  'Magnezone (#462)',
#  'No evolution[nb 4]',
#  'Dodrio (#085)',
#  'End of evolution',
#  'Dewgong (#087)',
#  'End of evolution',
#  'Muk (#089)',
#  'End of evolution',
#  'Cloyster (#091)',
#  'End of evolution',
#  'Haunter (#093)',
#  'Gengar (#094)',
#  'End of evolution',
#  'Steelix (#208)',
#  'Hypno (#097)',
#  'End of evolution',
#  'Kingler (#099)',
#  'End of evolution',
#  'Electrode (#101)',
#  'Electric',
#  'Exeggutor (#103)',
#  'End of evolution',
#  'Marowak (#105)',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'Lickilicky (#463)',
#  'Weezing (#110)',
#  'End of evolution',
#  'Rhydon (#112)',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'Seadra (#117)',
#  'End of evolution',
#  'Seaking (#119)',
#  'End of evolution',
#  'Starmie (#121)',
#  'End of evolution',
#  'End of evolutionEnd of evolution',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'No evolution',
#  'Gyarados (#130)',
#  'End of evolution',
#  'No evolution',
#  'No evolution',
#  'Multiple',
#  'End of Evolution',
#  'End of evolution',
#  'End of evolution',
#  'Porygon2 (#233)',
#  'Omastar (#139)',
#  'End of evolution',
#  'Kabutops (#141)',
#  'End of evolution',
#  'End of evolution',
#  'End of evolution',
#  'No evolution',
#  'No evolution',
#  'No evolution',
#  'Dragonair (#148)',
#  'Dragonite (#149)',
#  'End of evolution',
#  'End of evolution',
#  'No evolution']

# %% [markdown]
# Let's move on and add these columns to our DataFrame and proceed to load it to SQL

# %%
df['evolution'] = evolution
df['note'] = note

# %%
df.tail()
# Out:
#      number       name   type_1  type_2  total   hp  attack  defense  sp_atk  \
# 146     147    Dratini   Dragon     NaN    300   41      64       45      50
# 147     148  Dragonair   Dragon     NaN    420   61      84       65      70
# 148     149  Dragonite   Dragon  Flying    600   91     134       95     100
# 149     150     Mewtwo  Psychic     NaN    680  106     110       90     154
# 150     151        Mew  Psychic     NaN    600  100     100      100     100
#
#      sp_def  ...   color  hasgender height_m  weight_kg  catch_rate  \
# 146      50  ...    Blue       True     1.80        3.3          45
# 147      70  ...    Blue       True     3.99       16.5          45
# 148     100  ...   Brown       True     2.21      210.0          45
# 149      90  ...  Purple      False     2.01      122.0           3
# 150     100  ...    Pink      False     0.41        4.0          45
#
#           body_style                                        information  \
# 146  serpentine_body  Long considered a mythical POKéMON until recen...
# 147  serpentine_body  A mystical POKéMON that exudes a gentle aura. ...
# 148   bipedal_tailed  An extremely rarely seen marine POKéMON. Its i...
# 149   bipedal_tailed  It was created by a scientist after years of h...
# 150   bipedal_tailed  So rare that it is still said to be a mirage b...
#
#                                        api         evolution  \
# 146  https://pokeapi.co/api/v2/pokemon/147  Dragonair (#148)
# 147  https://pokeapi.co/api/v2/pokemon/148  Dragonite (#149)
# 148  https://pokeapi.co/api/v2/pokemon/149  End of evolution
# 149  https://pokeapi.co/api/v2/pokemon/150  End of evolution
# 150  https://pokeapi.co/api/v2/pokemon/151      No evolution
#
#                                                   note
# 146  Its existence was unknown until a fisherman pu...
# 147
# 148  Pseudo-Legendary. It zooms off over seas to ch...
# 149  Legendary. One of the playable characters in S...
# 150  Only available through Nintendo events. It can...
#
# [5 rows x 22 columns]

# %% [markdown]
# Finally, let's give an obvious name to our DataFrame:

# %%
pokedex = df

backup = pokedex.copy()

# %%
pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 150
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   number       151 non-null    int64
#  1   name         151 non-null    object
#  2   type_1       151 non-null    object
#  3   type_2       67 non-null     object
#  4   total        151 non-null    int64
#  5   hp           151 non-null    int64
#  6   attack       151 non-null    int64
#  7   defense      151 non-null    int64
#  8   sp_atk       151 non-null    int64
#  9   sp_def       151 non-null    int64
#  10  speed        151 non-null    int64
#  11  islegendary  151 non-null    bool
#  12  color        151 non-null    object
#  13  hasgender    151 non-null    bool
#  14  height_m     151 non-null    float64
#  15  weight_kg    151 non-null    float64
#  16  catch_rate   151 non-null    int64
#  17  body_style   151 non-null    object
#  18  information  151 non-null    object
#  19  api          151 non-null    object
#  20  evolution    151 non-null    object
#  21  note         151 non-null    object
# dtypes: bool(2), float64(2), int64(9), object(9)
# memory usage: 25.1+ KB

# %%
pokedex['type_2'].fillna('no type', inplace = True)

# %% [markdown]
# # Loading into SQL

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (8.0.24)
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from mysql-connector-python) (3.16.0)
# Requirement already satisfied: six>=1.9 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from protobuf>=3.0.0->mysql-connector-python) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import mysql.connector as conn

# %% [markdown]
# **DON'T RUN THE BELOW CODE**

# %% [markdown]
# def create_database(name, user = 'root', password = '*****', check=True):
#
#     create_database = conn.connect(host='localhost', user=user, passwd=password)
#
#     cursor = create_database.cursor()
#
#     cursor.execute(f'drop database if exists {name}')
#     cursor.execute(f'create database {name}')
#
#     print('Data Base created. ;)')
#
#     if check:
#         cursor.execute('show databases')
#         for x in cursor:
#             print(x)

# %%
create_database('pokemon')

# %% [markdown]
# def create_table(df, table_name, data_base, user='root', password='*****', check=True, drop=False):
#
#     db=conn.connect(host='localhost', user=user, passwd=password, database=data_base)
#     cursor=db.cursor()
#
#     if drop:
#         cursor.execute(f'drop table if exists {table_name}')
#
#     table = f"create table {table_name}(id int, {' varchar(255),'.join(df.columns)} varchar(2000));"
#     print(table)
#
#     cursor.execute(table)
#
#     print(f'Done, table {table_name} created. ;)')
#
#     if check:
#         cursor.execute('show tables')
#         for x in cursor:
#             print(x)

# %%
create_table(pokedex, '1gen' , 'pokemon')
# Out:
# create table 1gen(id int, number varchar(255),name varchar(255),type_1 varchar(255),type_2 varchar(255),total varchar(255),hp varchar(255),attack varchar(255),defense varchar(255),sp_atk varchar(255),sp_def varchar(255),speed varchar(255),islegendary varchar(255),color varchar(255),hasgender varchar(255),height_m varchar(255),weight_kg varchar(255),catch_rate varchar(255),body_style varchar(255),information varchar(255),api varchar(255),evolution varchar(255),note varchar(2000));
# Done, table 1gen created. ;)
# ('1gen',)

# %% [markdown]
# def insert_data(df, table_name, data_base, user='root', password= '*****'):
#
#     db = conn.connect(host='localhost', user=user, passwd=password, database=data_base)
#     cursor = db.cursor()
#
#     for i in range(len(df)):
#
#         insert_query = 'insert into {} (id, {}) values {};'\
#                      .format(table_name, ','.join(df.columns), tuple(np.insert(df.iloc[i].values, 0, i)))
#
#         cursor.execute(insert_query)
#
#     db.commit()
#     print(f'Done, data inserted into table {table_name}. ;)')
#     print()
#     print(insert_query)

# %%
insert_data(pokedex, '1gen' , 'pokemon')
# Out:
# Done, data inserted into table 1gen. ;)
#
# insert into 1gen (id, number,name,type_1,type_2,total,hp,attack,defense,sp_atk,sp_def,speed,islegendary,color,hasgender,height_m,weight_kg,catch_rate,body_style,information,api,evolution,note) values (150, 151, 'Mew', 'Psychic', 'no type', 600, 100, 100, 100, 100, 100, 100, False, 'Pink', False, 0.41, 4.0, 45, 'bipedal_tailed', 'So rare that it is still said to be a mirage by many experts. Only a few people have seen it worldwide.', 'https://pokeapi.co/api/v2/pokemon/151', 'No evolution', 'Only available through Nintendo events. It can turn invisible at will and it can turn into anything at will.');

# %% [markdown]
# def read_sql(query, table_name, data_base, user='root', password='*****'):
#
#     db = conn.connect(host='localhost', user=user, passwd=password, database=data_base)
#
#     data = pd.read_sql(query, db)
#
#     return data

# %%
read_sql('select * from 1gen limit 5', '1gen', 'pokemon')
# Out:
#    id number        name type_1   type_2 total  hp attack defense sp_atk  ...  \
# 0   0      1   Bulbasaur  Grass   Poison   318  45     49      49     65  ...
# 1   1      2     Ivysaur  Grass   Poison   405  60     62      63     80  ...
# 2   2      3    Venusaur  Grass   Poison   525  80     82      83    100  ...
# 3   3      4  Charmander   Fire  no type   309  39     52      43     60  ...
# 4   4      5  Charmeleon   Fire  no type   405  58     64      58     80  ...
#
#    color hasgender height_m weight_kg catch_rate      body_style  \
# 0  Green         1     0.71       6.9         45       quadruped
# 1  Green         1     0.99      13.0         45       quadruped
# 2  Green         1     2.01     100.0         45       quadruped
# 3    Red         1     0.61       8.5         45  bipedal_tailed
# 4    Red         1     1.09      19.0         45  bipedal_tailed
#
#                                          information  \
# 0  A strange seed was planted on its back at birt...
# 1  When the bulb on its back grows large, it appe...
# 2  The plant blooms when it is absorbing solar en...
# 3  Obviously prefers hot places. When it rains, s...
# 4  When it swings its burning tail, it elevates t...
#
#                                    api          evolution  \
# 0  https://pokeapi.co/api/v2/pokemon/1     Ivysaur (#002)
# 1  https://pokeapi.co/api/v2/pokemon/2    Venusaur (#003)
# 2  https://pokeapi.co/api/v2/pokemon/3   End of evolution
# 3  https://pokeapi.co/api/v2/pokemon/4  Charmeleon (#005)
# 4  https://pokeapi.co/api/v2/pokemon/5   Charizard (#006)
#
#                                                 note
# 0  Reception to Bulbasaur has been largely positi...
# 1  Playable character in Super Smash Bros. Brawl ...
# 2  [Gigantamax] Its English name is a portmanteau...
# 3  Charmander is a bipedal, salamander-like creat...
# 4  Charmeleon shares a nearly identical design to...
#
# [5 rows x 23 columns]
